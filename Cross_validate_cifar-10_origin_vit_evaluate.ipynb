# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import numpy as np
import pickle

import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from tensorflow import keras
from keras import models
from keras.models import Sequential
from keras.optimizers import Adam
import tensorflow as tf
import os
import copy

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 5
image_size = 72
num_heads = 4
projection_dim = 64
transformer_units = [
    projection_dim * 2,
    projection_dim
]
transformer_layers = 8
mlp_head_units = [2048, 1048] 

num_classes = 10
input_shape=(32,32,3)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation = tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images = images,
            sizes = [1, self.patch_size, self.patch_size, 1],
            strides = [1, self.patch_size, self.patch_size, 1],
            rates = [1, 1, 1, 1],
            padding = "VALID", 
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units = projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim = num_patches, output_dim = projection_dim
        )
    def call(self, patch):
        positions = tf.range(start = 0, limit = self.num_patches, delta = 1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_classifier(input_patch_size, input_data_augmentation):
    inputs = layers.Input(shape=input_shape)
    #augmented data
    augmented = input_data_augmentation(inputs)
    #create patches
    patches = Patches(input_patch_size)(augmented)
    # encode patches
    num_patches = (image_size // input_patch_size) ** 2
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer Block
    for _ in range(transformer_layers):
        # layer normalisation
        x1 = layers.LayerNormalization(epsilon= 1e-6)(encoded_patches)
        # Create a multi -  head attention layer
        attention_output = layers.MultiHeadAttention(
            num_heads = num_heads,
            key_dim = projection_dim,
            dropout = 0
        )(x1, x1)
        # Skip connection 1
        x2 = layers.Add()([attention_output, encoded_patches])
        #layer normalisation
        x3 = layers.LayerNormalization(epsilon = 1e-6)(x2)
        # MLP
        x2 = mlp(x3, hidden_units = transformer_units, dropout_rate = 0)
        # skip connection2
        encoded_patches =  layers.Add()([x3, x2])
    # Create a [batch_size, projection_dim] tensor
    representation = layers.LayerNormalization(epsilon = 1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0)(representation)

    # Add MLP 
    features = mlp(representation, hidden_units = mlp_head_units, dropout_rate = 0)
    #classify ouputs
    logits = layers.Dense(num_classes)(features)
    # Create the Keras Model
    model = keras.Model(inputs = inputs, outputs = logits)
    return model

# %%
def build_ViT_model(input_patch_size, input_data_augmentation):
    
    model = create_vit_classifier(input_patch_size, input_data_augmentation)
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )
    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy")
        ]
    )

    return model

# %%
# Run Noise_process before run this file

def get_dataset(obj_name):
    filename_labels = 'train_labels.npy'
    filename_origin = 'origin_cifar10.npy'
    filename_small_noise = 'small_noise_cifar10.npy'
    filename_medium_noise = 'medium_noise_cifar10.npy'
    filename_large_noise = 'large_noise_cifar10.npy'
    
    train_set = None
    s_size = 6000

    if obj_name == 'origin':
        train_set = np.load(filename_origin)[:s_size]
    elif obj_name == 'small_noise':
        train_set = np.load(filename_small_noise)[:s_size]
    elif obj_name == 'medium_noise':
        train_set = np.load(filename_medium_noise)[:s_size]
    elif obj_name == 'large_noise':
        train_set = np.load(filename_large_noise)[:s_size]
    else:
        raise ValueError(f"Unknown obj_name: {obj_name}")

    label_set = np.load(filename_labels)[:s_size] if train_set.size > 0 else None

    if label_set is None or train_set is None:
        print("Run Noise_process.ipynb before run this file")
    
    return train_set, label_set

# %%
def get_processed_dataset(model_name):
    train_set, label_set = get_dataset(model_name)

    return train_set, label_set

# %%
ORIGIN='origin'
SMALL='small_noise'
MEDIUM='medium_noise'
LARGE='large_noise'
all_dataset = [ORIGIN, SMALL, MEDIUM, LARGE]

# ViT: learning_rate, patch_size
best_config_origin_ViT = {'name': ORIGIN, 'patch_size': 12}
best_config_small_ViT = {'name': SMALL, 'patch_size': 12}
best_config_medium_ViT = {'name': MEDIUM, 'patch_size': 12}
best_config_large_ViT = {'name': LARGE, 'patch_size': 12}

best_config_ViT = []
best_config_ViT.append(best_config_origin_ViT)
best_config_ViT.append(best_config_small_ViT)
best_config_ViT.append(best_config_medium_ViT)
best_config_ViT.append(best_config_large_ViT)

# %%
def plot_learning_curves(all_history, model_name):
    train_loss = np.mean([h['loss'] for h in all_history], axis=0)
    val_loss = np.mean([h['val_loss'] for h in all_history], axis=0)
    train_accuracy = np.mean([h['accuracy'] for h in all_history], axis=0)
    val_accuracy = np.mean([h['val_accuracy'] for h in all_history], axis=0)

    plt.figure(figsize=(10, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(train_loss, label='Train Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title(f'Loss Curve {model_name} ViT')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracy, label='Train Accuracy')
    plt.plot(val_accuracy, label='Validation Accuracy')
    plt.title(f'Accuracy Curve {model_name} ViT')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.show()

# %%
all_performance_ViT = {}
all_histories = {}

for config in best_config_ViT:

    model_name = config['name']

    model_performance = {}

    # data
    # Use 80% for cross validation and 20% for robustness test for other model
    x_processed, y_processed = get_processed_dataset(model_name)
    x_cv, _, y_cv, _ = train_test_split(x_processed, y_processed, test_size=0.2, random_state=66, shuffle=True)
    
    data_augmentation = keras.Sequential(
        [
            layers.Normalization(),
            layers.Resizing(image_size, image_size)
        ],
        name = "data_augmentation"
    )
    data_augmentation.layers[0].adapt(x_processed)
    


    # Cross Validation
    kf = KFold(n_splits=20, shuffle=True, random_state=66)
    all_history = []

    for fold, (train_index, val_index) in enumerate(kf.split(x_cv)):
        print(f'Fold {fold + 1}/{20}')
        
        model = build_ViT_model(config['patch_size'], data_augmentation)
        
        x_train, x_val = x_cv[train_index], x_cv[val_index]
        y_train, y_val = y_cv[train_index], y_cv[val_index]
        
        history = model.fit(x_train, y_train, epochs=5, batch_size=128, validation_data=(x_val, y_val), verbose=0)
        all_history.append(history.history)
        model_performance_fold = {}


        # Robustness Test
        for dataset_name in all_dataset:
            if dataset_name == model_name:
                # Do robustness evaluations on other dataset
                continue
            # Get rest part of dataset which never used on Cross Validation
            x_evaluated, y_evaluated = get_processed_dataset(dataset_name)
            _, x_test, _, y_test = train_test_split(x_evaluated, y_evaluated, test_size=0.2, random_state=66, shuffle=True)

            y_pred = model.predict(x_test)
            y_pred_classes = np.argmax(y_pred, axis=1)
            y_true_classes = y_test
            # y_true_classes = np.argmax(y_test, axis=1) 

            accuracy = accuracy_score(y_true_classes, y_pred_classes)
            precision = precision_score(y_true_classes, y_pred_classes, average='macro', zero_division=0)
            recall = recall_score(y_true_classes, y_pred_classes, average='macro', zero_division=0)

            print(f"Run {model_name}, in {dataset_name} at Fold {fold + 1}/{20}: Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}")
            # print(f"y_pred: {y_pred}, y_pred_classes: {y_pred_classes}, y_test: {y_test}, y_true_classes: {y_true_classes}")
        
        
            model_performance_fold[dataset_name] = {'accuracy' : accuracy, 'precision' : precision, 'recall' : recall}

            
        model_performance[fold+1] = model_performance_fold

    all_performance_ViT[model_name] = model_performance

    plot_learning_curves(all_history, model_name)
    all_histories[model_name] = all_history
# Out:
# Fold 1/20
# 38/38 [==============================] - 2s 42ms/step
# Run origin, in small_noise at Fold 1/20: Accuracy: 0.45166666666666666, Precision: 0.4605623826103512, Recall: 0.45313301731441
# 38/38 [==============================] - 2s 42ms/step
# Run origin, in medium_noise at Fold 1/20: Accuracy: 0.42833333333333334, Precision: 0.4340189535625921, Recall: 0.42921897849782764
# 38/38 [==============================] - 2s 46ms/step
# Run origin, in large_noise at Fold 1/20: Accuracy: 0.3175, Precision: 0.3778607118921429, Recall: 0.31707361648505483
# Fold 2/20
# 38/38 [==============================] - 2s 43ms/step
# Run origin, in small_noise at Fold 2/20: Accuracy: 0.44583333333333336, Precision: 0.46907619359633923, Recall: 0.4426832059768455
# 38/38 [==============================] - 2s 46ms/step
# Run origin, in medium_noise at Fold 2/20: Accuracy: 0.43166666666666664, Precision: 0.4491061135914228, Recall: 0.4290067539557511
# 38/38 [==============================] - 2s 48ms/step
# Run origin, in large_noise at Fold 2/20: Accuracy: 0.30666666666666664, Precision: 0.36815383326070694, Recall: 0.30607954603362464
# Fold 3/20
# 38/38 [==============================] - 2s 42ms/step
# Run origin, in small_noise at Fold 3/20: Accuracy: 0.4575, Precision: 0.4702720573621015, Recall: 0.45963831587645726
# 38/38 [==============================] - 2s 42ms/step
# Run origin, in medium_noise at Fold 3/20: Accuracy: 0.45416666666666666, Precision: 0.463198281712572, Recall: 0.4556018337163648
# 38/38 [==============================] - 2s 42ms/step
# Run origin, in large_noise at Fold 3/20: Accuracy: 0.32916666666666666, Precision: 0.4290083241038435, Recall: 0.33258251657815624
# Fold 4/20
# 38/38 [==============================] - 3s 60ms/step
# Run origin, in small_noise at Fold 4/20: Accuracy: 0.445, Precision: 0.4690498988786553, Recall: 0.44348190441185464
# 38/38 [==============================] - 2s 57ms/step
# Run origin, in medium_noise at Fold 4/20: Accuracy: 0.41583333333333333, Precision: 0.4347529674912479, Recall: 0.41503937704680655
# 38/38 [==============================] - 2s 56ms/step
# Run origin, in large_noise at Fold 4/20: Accuracy: 0.3333333333333333, Precision: 0.41750188745388456, Recall: 0.3312263905291465
# Fold 5/20
# 38/38 [==============================] - 3s 54ms/step
# Run origin, in small_noise at Fold 5/20: Accuracy: 0.47833333333333333, Precision: 0.4781110149800069, Recall: 0.4760024489481333
# 38/38 [==============================] - 2s 55ms/step
# Run origin, in medium_noise at Fold 5/20: Accuracy: 0.4525, Precision: 0.45095938096920224, Recall: 0.4503153282653821
# 38/38 [==============================] - 2s 55ms/step
# Run origin, in large_noise at Fold 5/20: Accuracy: 0.3541666666666667, Precision: 0.4303677929981057, Recall: 0.35228310821916997
# Fold 6/20
# 38/38 [==============================] - 3s 62ms/step
# Run origin, in small_noise at Fold 6/20: Accuracy: 0.44083333333333335, Precision: 0.4560370392011279, Recall: 0.4411007007435928
# 38/38 [==============================] - 2s 61ms/step
# Run origin, in medium_noise at Fold 6/20: Accuracy: 0.4083333333333333, Precision: 0.42606914973990706, Recall: 0.40826778252182655
# 38/38 [==============================] - 2s 61ms/step
# Run origin, in large_noise at Fold 6/20: Accuracy: 0.3225, Precision: 0.40067800745469195, Recall: 0.32713626930355616
# Fold 7/20
# 38/38 [==============================] - 3s 61ms/step
# Run origin, in small_noise at Fold 7/20: Accuracy: 0.4625, Precision: 0.47341671291451315, Recall: 0.4646922985501873
# 38/38 [==============================] - 2s 58ms/step
# Run origin, in medium_noise at Fold 7/20: Accuracy: 0.4475, Precision: 0.4516173777601467, Recall: 0.4490088996471993
# 38/38 [==============================] - 2s 58ms/step
# Run origin, in large_noise at Fold 7/20: Accuracy: 0.3458333333333333, Precision: 0.3946721461311541, Recall: 0.35033281432638586
# Fold 8/20
# 38/38 [==============================] - 3s 61ms/step
# Run origin, in small_noise at Fold 8/20: Accuracy: 0.4608333333333333, Precision: 0.47633910218576353, Recall: 0.4636866996104122
# 38/38 [==============================] - 2s 57ms/step
# Run origin, in medium_noise at Fold 8/20: Accuracy: 0.46416666666666667, Precision: 0.4707528994301077, Recall: 0.46557390494258033
# 38/38 [==============================] - 2s 61ms/step
# Run origin, in large_noise at Fold 8/20: Accuracy: 0.335, Precision: 0.41211897363503824, Recall: 0.33795104061442083
# Fold 9/20
# 38/38 [==============================] - 3s 70ms/step
# Run origin, in small_noise at Fold 9/20: Accuracy: 0.4508333333333333, Precision: 0.4667494068940491, Recall: 0.45122974771365787
# 38/38 [==============================] - 3s 70ms/step
# Run origin, in medium_noise at Fold 9/20: Accuracy: 0.4241666666666667, Precision: 0.43978706186513356, Recall: 0.4234426875775926
# 38/38 [==============================] - 3s 66ms/step
# Run origin, in large_noise at Fold 9/20: Accuracy: 0.3466666666666667, Precision: 0.42153366324381275, Recall: 0.3491842440603844
# Fold 10/20
# 38/38 [==============================] - 3s 62ms/step
# Run origin, in small_noise at Fold 10/20: Accuracy: 0.44666666666666666, Precision: 0.47246710322553626, Recall: 0.44636683650602843
# 38/38 [==============================] - 2s 60ms/step
# Run origin, in medium_noise at Fold 10/20: Accuracy: 0.4325, Precision: 0.45637062501959996, Recall: 0.43264932058879396
# 38/38 [==============================] - 2s 59ms/step
# Run origin, in large_noise at Fold 10/20: Accuracy: 0.33166666666666667, Precision: 0.4232789531622907, Recall: 0.3304506919844935
# Fold 11/20
# 38/38 [==============================] - 3s 66ms/step
# Run origin, in small_noise at Fold 11/20: Accuracy: 0.44666666666666666, Precision: 0.4771789040202856, Recall: 0.44790126782893536
# 38/38 [==============================] - 2s 65ms/step
# Run origin, in medium_noise at Fold 11/20: Accuracy: 0.43416666666666665, Precision: 0.4487376073016585, Recall: 0.43504784321192325
# 38/38 [==============================] - 2s 64ms/step
# Run origin, in large_noise at Fold 11/20: Accuracy: 0.30666666666666664, Precision: 0.39391702105485626, Recall: 0.31111508592792236
# Fold 12/20
# 38/38 [==============================] - 3s 60ms/step
# Run origin, in small_noise at Fold 12/20: Accuracy: 0.4275, Precision: 0.4354329124641739, Recall: 0.42602629609454745
# 38/38 [==============================] - 2s 59ms/step
# Run origin, in medium_noise at Fold 12/20: Accuracy: 0.42916666666666664, Precision: 0.43443184521288847, Recall: 0.4270548492342778
# 38/38 [==============================] - 2s 59ms/step
# Run origin, in large_noise at Fold 12/20: Accuracy: 0.3258333333333333, Precision: 0.40203759814550866, Recall: 0.3242224319832226
# Fold 13/20
# 38/38 [==============================] - 3s 59ms/step
# Run origin, in small_noise at Fold 13/20: Accuracy: 0.46, Precision: 0.46611794920898697, Recall: 0.45872975165061236
# 38/38 [==============================] - 2s 60ms/step
# Run origin, in medium_noise at Fold 13/20: Accuracy: 0.44416666666666665, Precision: 0.451187550257757, Recall: 0.4431729824365716
# 38/38 [==============================] - 2s 59ms/step
# Run origin, in large_noise at Fold 13/20: Accuracy: 0.3233333333333333, Precision: 0.382884584849624, Recall: 0.3247800573272995
# Fold 14/20
# 38/38 [==============================] - 3s 66ms/step
# Run origin, in small_noise at Fold 14/20: Accuracy: 0.48, Precision: 0.48411662331396493, Recall: 0.4816441696172838
# 38/38 [==============================] - 2s 63ms/step
# Run origin, in medium_noise at Fold 14/20: Accuracy: 0.4575, Precision: 0.45491278410426395, Recall: 0.45911236080794177
# 38/38 [==============================] - 2s 63ms/step
# Run origin, in large_noise at Fold 14/20: Accuracy: 0.3375, Precision: 0.374365711402656, Recall: 0.3388267101900541
# Fold 15/20
# 38/38 [==============================] - 3s 61ms/step
# Run origin, in small_noise at Fold 15/20: Accuracy: 0.45, Precision: 0.4659682441615479, Recall: 0.4522193495775352
# 38/38 [==============================] - 2s 62ms/step
# Run origin, in medium_noise at Fold 15/20: Accuracy: 0.42833333333333334, Precision: 0.43958074248445167, Recall: 0.43024877480597856
# 38/38 [==============================] - 2s 62ms/step
# Run origin, in large_noise at Fold 15/20: Accuracy: 0.31333333333333335, Precision: 0.403860018349081, Recall: 0.31867669781966634
# Fold 16/20
# 38/38 [==============================] - 3s 68ms/step
# Run origin, in small_noise at Fold 16/20: Accuracy: 0.4716666666666667, Precision: 0.4750819294726055, Recall: 0.4745790623120156
# 38/38 [==============================] - 3s 68ms/step
# Run origin, in medium_noise at Fold 16/20: Accuracy: 0.4666666666666667, Precision: 0.46594924731470666, Recall: 0.46883483032943285
# 38/38 [==============================] - 3s 67ms/step
# Run origin, in large_noise at Fold 16/20: Accuracy: 0.32666666666666666, Precision: 0.3972407337739113, Recall: 0.33136779224694585
# Fold 17/20
# 38/38 [==============================] - 3s 64ms/step
# Run origin, in small_noise at Fold 17/20: Accuracy: 0.465, Precision: 0.47112728267612736, Recall: 0.4641464998136963
# 38/38 [==============================] - 2s 64ms/step
# Run origin, in medium_noise at Fold 17/20: Accuracy: 0.4533333333333333, Precision: 0.46494188568240824, Recall: 0.45265923169276645
# 38/38 [==============================] - 3s 66ms/step
# Run origin, in large_noise at Fold 17/20: Accuracy: 0.3383333333333333, Precision: 0.38749209817310365, Recall: 0.33767296866732793
# Fold 18/20
# 38/38 [==============================] - 3s 76ms/step
# Run origin, in small_noise at Fold 18/20: Accuracy: 0.4533333333333333, Precision: 0.46923680502652176, Recall: 0.45190016741139194
# 38/38 [==============================] - 3s 77ms/step
# Run origin, in medium_noise at Fold 18/20: Accuracy: 0.445, Precision: 0.46004662116367123, Recall: 0.44586725428742574
# 38/38 [==============================] - 3s 75ms/step
# Run origin, in large_noise at Fold 18/20: Accuracy: 0.30083333333333334, Precision: 0.36448005541333883, Recall: 0.3007835539975263
# Fold 19/20
# 38/38 [==============================] - 4s 85ms/step
# Run origin, in small_noise at Fold 19/20: Accuracy: 0.43166666666666664, Precision: 0.4569323587074451, Recall: 0.4322912792113547
# 38/38 [==============================] - 3s 87ms/step
# Run origin, in medium_noise at Fold 19/20: Accuracy: 0.41583333333333333, Precision: 0.4428850429107545, Recall: 0.4158317640707573
# 38/38 [==============================] - 3s 89ms/step
# Run origin, in large_noise at Fold 19/20: Accuracy: 0.31416666666666665, Precision: 0.4141740603100099, Recall: 0.31657639345116545
# Fold 20/20
# 38/38 [==============================] - 3s 71ms/step
# Run origin, in small_noise at Fold 20/20: Accuracy: 0.4483333333333333, Precision: 0.46012908342687525, Recall: 0.44785412010668546
# 38/38 [==============================] - 3s 73ms/step
# Run origin, in medium_noise at Fold 20/20: Accuracy: 0.43, Precision: 0.44154459220075815, Recall: 0.42728727738068784
# 38/38 [==============================] - 3s 71ms/step
# Run origin, in large_noise at Fold 20/20: Accuracy: 0.335, Precision: 0.368296853861828, Recall: 0.3355916808255127
# Fold 1/20
# 38/38 [==============================] - 3s 65ms/step
# Run small_noise, in origin at Fold 1/20: Accuracy: 0.4483333333333333, Precision: 0.44926866062298976, Recall: 0.45002361888428577
# 38/38 [==============================] - 2s 65ms/step
# Run small_noise, in medium_noise at Fold 1/20: Accuracy: 0.4091666666666667, Precision: 0.4085217560651066, Recall: 0.41085350642596125
# 38/38 [==============================] - 2s 65ms/step
# Run small_noise, in large_noise at Fold 1/20: Accuracy: 0.3491666666666667, Precision: 0.40445820932089677, Recall: 0.3508931123548571
# Fold 2/20
# 38/38 [==============================] - 4s 87ms/step
# Run small_noise, in origin at Fold 2/20: Accuracy: 0.44916666666666666, Precision: 0.44602856612066344, Recall: 0.4491742172539335
# 38/38 [==============================] - 3s 86ms/step
# Run small_noise, in medium_noise at Fold 2/20: Accuracy: 0.425, Precision: 0.42193992202650243, Recall: 0.42493859085846947
# 38/38 [==============================] - 3s 86ms/step
# Run small_noise, in large_noise at Fold 2/20: Accuracy: 0.35583333333333333, Precision: 0.413259638124733, Recall: 0.3541736645466142
# Fold 3/20
# 38/38 [==============================] - 4s 86ms/step
# Run small_noise, in origin at Fold 3/20: Accuracy: 0.45416666666666666, Precision: 0.4651304024782924, Recall: 0.4540336046964118
# 38/38 [==============================] - 3s 86ms/step
# Run small_noise, in medium_noise at Fold 3/20: Accuracy: 0.42, Precision: 0.4408823917375312, Recall: 0.41962302833790366
# 38/38 [==============================] - 3s 86ms/step
# Run small_noise, in large_noise at Fold 3/20: Accuracy: 0.335, Precision: 0.4059772306452927, Recall: 0.33652461339224626
# Fold 4/20
# 38/38 [==============================] - 4s 78ms/step
# Run small_noise, in origin at Fold 4/20: Accuracy: 0.4558333333333333, Precision: 0.4621282924129771, Recall: 0.4570536111286316
# 38/38 [==============================] - 3s 79ms/step
# Run small_noise, in medium_noise at Fold 4/20: Accuracy: 0.4266666666666667, Precision: 0.4351421704668875, Recall: 0.4275304025058442
# 38/38 [==============================] - 3s 79ms/step
# Run small_noise, in large_noise at Fold 4/20: Accuracy: 0.35, Precision: 0.3876420500660549, Recall: 0.34902876533177524
# Fold 5/20
# 38/38 [==============================] - 3s 68ms/step
# Run small_noise, in origin at Fold 5/20: Accuracy: 0.47333333333333333, Precision: 0.4741424159156173, Recall: 0.47244639546804146
# 38/38 [==============================] - 3s 67ms/step
# Run small_noise, in medium_noise at Fold 5/20: Accuracy: 0.43916666666666665, Precision: 0.4428098514595235, Recall: 0.438283960914757
# 38/38 [==============================] - 3s 67ms/step
# Run small_noise, in large_noise at Fold 5/20: Accuracy: 0.3458333333333333, Precision: 0.39840594708182053, Recall: 0.34448425684729445
# Fold 6/20
# 38/38 [==============================] - 3s 63ms/step
# Run small_noise, in origin at Fold 6/20: Accuracy: 0.44916666666666666, Precision: 0.47444491306258463, Recall: 0.45074706607991394
# 38/38 [==============================] - 2s 63ms/step
# Run small_noise, in medium_noise at Fold 6/20: Accuracy: 0.42833333333333334, Precision: 0.4554134430022825, Recall: 0.42998595894236064
# 38/38 [==============================] - 2s 63ms/step
# Run small_noise, in large_noise at Fold 6/20: Accuracy: 0.29333333333333333, Precision: 0.38561665555286423, Recall: 0.29613102244989203
# Fold 7/20
# 38/38 [==============================] - 3s 69ms/step
# Run small_noise, in origin at Fold 7/20: Accuracy: 0.4558333333333333, Precision: 0.476914534999925, Recall: 0.45606114530432373
# 38/38 [==============================] - 3s 66ms/step
# Run small_noise, in medium_noise at Fold 7/20: Accuracy: 0.435, Precision: 0.4491036866602027, Recall: 0.43451750988845295
# 38/38 [==============================] - 3s 66ms/step
# Run small_noise, in large_noise at Fold 7/20: Accuracy: 0.33916666666666667, Precision: 0.4191017940453675, Recall: 0.3434392171786781
# Fold 8/20
# 38/38 [==============================] - 3s 69ms/step
# Run small_noise, in origin at Fold 8/20: Accuracy: 0.44916666666666666, Precision: 0.46581360006015454, Recall: 0.45018048069876315
# 38/38 [==============================] - 3s 71ms/step
# Run small_noise, in medium_noise at Fold 8/20: Accuracy: 0.4175, Precision: 0.4343156663033321, Recall: 0.4187420147463894
# 38/38 [==============================] - 3s 70ms/step
# Run small_noise, in large_noise at Fold 8/20: Accuracy: 0.31833333333333336, Precision: 0.3776090423776052, Recall: 0.3179045953977649
# Fold 9/20
# 38/38 [==============================] - 3s 74ms/step
# Run small_noise, in origin at Fold 9/20: Accuracy: 0.4608333333333333, Precision: 0.467980580589491, Recall: 0.46399766866157705
# 38/38 [==============================] - 3s 73ms/step
# Run small_noise, in medium_noise at Fold 9/20: Accuracy: 0.43583333333333335, Precision: 0.4397928699280791, Recall: 0.43858325046222274
# 38/38 [==============================] - 3s 72ms/step
# Run small_noise, in large_noise at Fold 9/20: Accuracy: 0.3408333333333333, Precision: 0.3739444803303338, Recall: 0.34383998607317484
# Fold 10/20
# 38/38 [==============================] - 3s 75ms/step
# Run small_noise, in origin at Fold 10/20: Accuracy: 0.45416666666666666, Precision: 0.46173111822116625, Recall: 0.4554030708298331
# 38/38 [==============================] - 3s 74ms/step
# Run small_noise, in medium_noise at Fold 10/20: Accuracy: 0.43833333333333335, Precision: 0.442727403268038, Recall: 0.4386625351095506
# 38/38 [==============================] - 3s 74ms/step
# Run small_noise, in large_noise at Fold 10/20: Accuracy: 0.3625, Precision: 0.41505632125591596, Recall: 0.3642824736568684
# Fold 11/20
# 38/38 [==============================] - 3s 75ms/step
# Run small_noise, in origin at Fold 11/20: Accuracy: 0.46166666666666667, Precision: 0.48097559590496397, Recall: 0.46394427326275506
# 38/38 [==============================] - 3s 74ms/step
# Run small_noise, in medium_noise at Fold 11/20: Accuracy: 0.43916666666666665, Precision: 0.46004781661800315, Recall: 0.4412768791823501
# 38/38 [==============================] - 3s 74ms/step
# Run small_noise, in large_noise at Fold 11/20: Accuracy: 0.365, Precision: 0.44484450961777416, Recall: 0.3658922373515582
# Fold 12/20
# 38/38 [==============================] - 4s 81ms/step
# Run small_noise, in origin at Fold 12/20: Accuracy: 0.4633333333333333, Precision: 0.46495858401452317, Recall: 0.46287198930268875
# 38/38 [==============================] - 3s 79ms/step
# Run small_noise, in medium_noise at Fold 12/20: Accuracy: 0.4425, Precision: 0.4423711322306092, Recall: 0.44150134656314216
# 38/38 [==============================] - 3s 79ms/step
# Run small_noise, in large_noise at Fold 12/20: Accuracy: 0.3575, Precision: 0.3987810743590096, Recall: 0.35503663096431287
# Fold 13/20
# 38/38 [==============================] - 4s 91ms/step
# Run small_noise, in origin at Fold 13/20: Accuracy: 0.44583333333333336, Precision: 0.4767559826666698, Recall: 0.4434104737027355
# 38/38 [==============================] - 3s 91ms/step
# Run small_noise, in medium_noise at Fold 13/20: Accuracy: 0.42, Precision: 0.45919233620193645, Recall: 0.41750294995328857
# 38/38 [==============================] - 4s 92ms/step
# Run small_noise, in large_noise at Fold 13/20: Accuracy: 0.325, Precision: 0.40584153964126807, Recall: 0.3246817041539231
# Fold 14/20
# 38/38 [==============================] - 4s 87ms/step
# Run small_noise, in origin at Fold 14/20: Accuracy: 0.43833333333333335, Precision: 0.4448940309035625, Recall: 0.43645191298515656
# 38/38 [==============================] - 3s 86ms/step
# Run small_noise, in medium_noise at Fold 14/20: Accuracy: 0.4175, Precision: 0.4246784276257155, Recall: 0.4155248771059778
# 38/38 [==============================] - 3s 87ms/step
# Run small_noise, in large_noise at Fold 14/20: Accuracy: 0.3475, Precision: 0.39076779183768906, Recall: 0.34585189622606255
# Fold 15/20
# 38/38 [==============================] - 3s 76ms/step
# Run small_noise, in origin at Fold 15/20: Accuracy: 0.4325, Precision: 0.43240089667659465, Recall: 0.4317195295838685
# 38/38 [==============================] - 3s 76ms/step
# Run small_noise, in medium_noise at Fold 15/20: Accuracy: 0.415, Precision: 0.416029501685866, Recall: 0.4142411418062892
# 38/38 [==============================] - 3s 78ms/step
# Run small_noise, in large_noise at Fold 15/20: Accuracy: 0.31583333333333335, Precision: 0.376786138877342, Recall: 0.3137698951249256
# Fold 16/20
# 38/38 [==============================] - 4s 86ms/step
# Run small_noise, in origin at Fold 16/20: Accuracy: 0.45166666666666666, Precision: 0.45665135496336406, Recall: 0.45189710093264984
# 38/38 [==============================] - 3s 90ms/step
# Run small_noise, in medium_noise at Fold 16/20: Accuracy: 0.4191666666666667, Precision: 0.4201319822986638, Recall: 0.4199265181422377
# 38/38 [==============================] - 3s 91ms/step
# Run small_noise, in large_noise at Fold 16/20: Accuracy: 0.3441666666666667, Precision: 0.41790589166322867, Recall: 0.34634811971442003
# Fold 17/20
# 38/38 [==============================] - 4s 96ms/step
# Run small_noise, in origin at Fold 17/20: Accuracy: 0.435, Precision: 0.43312869263098985, Recall: 0.4304775099757876
# 38/38 [==============================] - 4s 105ms/step
# Run small_noise, in medium_noise at Fold 17/20: Accuracy: 0.43833333333333335, Precision: 0.4397754861402892, Recall: 0.43440015047434644
# 38/38 [==============================] - 4s 101ms/step
# Run small_noise, in large_noise at Fold 17/20: Accuracy: 0.32416666666666666, Precision: 0.37675680313837423, Recall: 0.32125220818135974
# Fold 18/20
# 38/38 [==============================] - 5s 102ms/step
# Run small_noise, in origin at Fold 18/20: Accuracy: 0.455, Precision: 0.4545335256961615, Recall: 0.45465821106241355
# 38/38 [==============================] - 4s 93ms/step
# Run small_noise, in medium_noise at Fold 18/20: Accuracy: 0.43333333333333335, Precision: 0.4340867404263384, Recall: 0.43231060102044927
# 38/38 [==============================] - 3s 92ms/step
# Run small_noise, in large_noise at Fold 18/20: Accuracy: 0.29, Precision: 0.3593319904081899, Recall: 0.290250274472439
# Fold 19/20
# 38/38 [==============================] - 5s 102ms/step
# Run small_noise, in origin at Fold 19/20: Accuracy: 0.43666666666666665, Precision: 0.43215726224261486, Recall: 0.436992068868377
# 38/38 [==============================] - 4s 105ms/step
# Run small_noise, in medium_noise at Fold 19/20: Accuracy: 0.4175, Precision: 0.41729781247438236, Recall: 0.4188245450032344
# 38/38 [==============================] - 4s 108ms/step
# Run small_noise, in large_noise at Fold 19/20: Accuracy: 0.33, Precision: 0.36606864036088205, Recall: 0.32985394820778424
# Fold 20/20
# 38/38 [==============================] - 4s 94ms/step
# Run small_noise, in origin at Fold 20/20: Accuracy: 0.4625, Precision: 0.48093654768390975, Recall: 0.46311138127494056
# 38/38 [==============================] - 4s 94ms/step
# Run small_noise, in medium_noise at Fold 20/20: Accuracy: 0.4266666666666667, Precision: 0.43897793025413073, Recall: 0.42732820146006817
# 38/38 [==============================] - 4s 94ms/step
# Run small_noise, in large_noise at Fold 20/20: Accuracy: 0.35583333333333333, Precision: 0.3921188798107915, Recall: 0.3555800178248093
# Fold 1/20
# 38/38 [==============================] - 4s 85ms/step
# Run medium_noise, in origin at Fold 1/20: Accuracy: 0.4658333333333333, Precision: 0.4722375042621487, Recall: 0.4650483326278481
# 38/38 [==============================] - 4s 93ms/step
# Run medium_noise, in small_noise at Fold 1/20: Accuracy: 0.4508333333333333, Precision: 0.4628574134204567, Recall: 0.4497891997632433
# 38/38 [==============================] - 3s 92ms/step
# Run medium_noise, in large_noise at Fold 1/20: Accuracy: 0.30666666666666664, Precision: 0.3993918157791023, Recall: 0.30833450247418465
# Fold 2/20
# 38/38 [==============================] - 5s 108ms/step
# Run medium_noise, in origin at Fold 2/20: Accuracy: 0.43166666666666664, Precision: 0.43529272378621026, Recall: 0.43219528290359827
# 38/38 [==============================] - 4s 108ms/step
# Run medium_noise, in small_noise at Fold 2/20: Accuracy: 0.42833333333333334, Precision: 0.44036775571183684, Recall: 0.4287360259720464
# 38/38 [==============================] - 4s 106ms/step
# Run medium_noise, in large_noise at Fold 2/20: Accuracy: 0.29, Precision: 0.3631713660203439, Recall: 0.29223541404784303
# Fold 3/20
# 38/38 [==============================] - 4s 99ms/step
# Run medium_noise, in origin at Fold 3/20: Accuracy: 0.43916666666666665, Precision: 0.4383235956757245, Recall: 0.43960171237605933
# 38/38 [==============================] - 4s 96ms/step
# Run medium_noise, in small_noise at Fold 3/20: Accuracy: 0.44666666666666666, Precision: 0.4504842412745467, Recall: 0.4469668820485112
# 38/38 [==============================] - 4s 96ms/step
# Run medium_noise, in large_noise at Fold 3/20: Accuracy: 0.3225, Precision: 0.3749316322083467, Recall: 0.32222435308937414
# Fold 4/20
# 38/38 [==============================] - 4s 95ms/step
# Run medium_noise, in origin at Fold 4/20: Accuracy: 0.4816666666666667, Precision: 0.475286260621303, Recall: 0.4799297827197157
# 38/38 [==============================] - 4s 103ms/step
# Run medium_noise, in small_noise at Fold 4/20: Accuracy: 0.485, Precision: 0.48167535465910466, Recall: 0.48346411795226285
# 38/38 [==============================] - 4s 100ms/step
# Run medium_noise, in large_noise at Fold 4/20: Accuracy: 0.34833333333333333, Precision: 0.42132613910332406, Recall: 0.34595952088979715
# Fold 5/20
# 38/38 [==============================] - 4s 81ms/step
# Run medium_noise, in origin at Fold 5/20: Accuracy: 0.435, Precision: 0.4318954406858183, Recall: 0.4352978226692392
# 38/38 [==============================] - 3s 81ms/step
# Run medium_noise, in small_noise at Fold 5/20: Accuracy: 0.425, Precision: 0.42577570353373523, Recall: 0.4252417932321039
# 38/38 [==============================] - 3s 81ms/step
# Run medium_noise, in large_noise at Fold 5/20: Accuracy: 0.29083333333333333, Precision: 0.3669965248166468, Recall: 0.2930849624160588
# Fold 6/20
# 38/38 [==============================] - 4s 85ms/step
# Run medium_noise, in origin at Fold 6/20: Accuracy: 0.43583333333333335, Precision: 0.4535036629305381, Recall: 0.434548939382086
# 38/38 [==============================] - 3s 84ms/step
# Run medium_noise, in small_noise at Fold 6/20: Accuracy: 0.42583333333333334, Precision: 0.45851619531907845, Recall: 0.4253095204029985
# 38/38 [==============================] - 3s 87ms/step
# Run medium_noise, in large_noise at Fold 6/20: Accuracy: 0.2683333333333333, Precision: 0.38100196336143044, Recall: 0.2694719230644632
# Fold 7/20
# 38/38 [==============================] - 4s 83ms/step
# Run medium_noise, in origin at Fold 7/20: Accuracy: 0.4708333333333333, Precision: 0.4747804894105022, Recall: 0.4691623936906277
# 38/38 [==============================] - 3s 83ms/step
# Run medium_noise, in small_noise at Fold 7/20: Accuracy: 0.46166666666666667, Precision: 0.4764420201855602, Recall: 0.4604295403639683
# 38/38 [==============================] - 3s 82ms/step
# Run medium_noise, in large_noise at Fold 7/20: Accuracy: 0.32166666666666666, Precision: 0.405719690810005, Recall: 0.3204090444973493
# Fold 8/20
# 38/38 [==============================] - 4s 81ms/step
# Run medium_noise, in origin at Fold 8/20: Accuracy: 0.4533333333333333, Precision: 0.4598812044846533, Recall: 0.4537928750189881
# 38/38 [==============================] - 3s 79ms/step
# Run medium_noise, in small_noise at Fold 8/20: Accuracy: 0.44083333333333335, Precision: 0.45640527715503715, Recall: 0.4411483549974652
# 38/38 [==============================] - 3s 79ms/step
# Run medium_noise, in large_noise at Fold 8/20: Accuracy: 0.29333333333333333, Precision: 0.3680647681756103, Recall: 0.2929415940710539
# Fold 9/20
# 38/38 [==============================] - 4s 77ms/step
# Run medium_noise, in origin at Fold 9/20: Accuracy: 0.44916666666666666, Precision: 0.4537790458879657, Recall: 0.4517319626849711
# 38/38 [==============================] - 3s 77ms/step
# Run medium_noise, in small_noise at Fold 9/20: Accuracy: 0.44916666666666666, Precision: 0.4537845119457794, Recall: 0.4511789853313708
# 38/38 [==============================] - 3s 78ms/step
# Run medium_noise, in large_noise at Fold 9/20: Accuracy: 0.34, Precision: 0.3898306209062679, Recall: 0.34117310229955183
# Fold 10/20
# 38/38 [==============================] - 4s 83ms/step
# Run medium_noise, in origin at Fold 10/20: Accuracy: 0.4633333333333333, Precision: 0.46606077931522305, Recall: 0.46433378327223407
# 38/38 [==============================] - 3s 81ms/step
# Run medium_noise, in small_noise at Fold 10/20: Accuracy: 0.4533333333333333, Precision: 0.4631344796386386, Recall: 0.4542745884777683
# 38/38 [==============================] - 3s 82ms/step
# Run medium_noise, in large_noise at Fold 10/20: Accuracy: 0.31083333333333335, Precision: 0.4000023203904621, Recall: 0.30987243194288205
# Fold 11/20
# 38/38 [==============================] - 5s 99ms/step
# Run medium_noise, in origin at Fold 11/20: Accuracy: 0.4725, Precision: 0.46786708608967287, Recall: 0.47060912050062714
# 38/38 [==============================] - 4s 101ms/step
# Run medium_noise, in small_noise at Fold 11/20: Accuracy: 0.4675, Precision: 0.46511127466399194, Recall: 0.4659592768686485
# 38/38 [==============================] - 4s 105ms/step
# Run medium_noise, in large_noise at Fold 11/20: Accuracy: 0.32083333333333336, Precision: 0.392484125286988, Recall: 0.32164985745476904
# Fold 12/20
# 38/38 [==============================] - 4s 94ms/step
# Run medium_noise, in origin at Fold 12/20: Accuracy: 0.45166666666666666, Precision: 0.45363050625655743, Recall: 0.4521753732734769
# 38/38 [==============================] - 4s 95ms/step
# Run medium_noise, in small_noise at Fold 12/20: Accuracy: 0.43666666666666665, Precision: 0.44216515583638455, Recall: 0.43772546701219267
# 38/38 [==============================] - 4s 96ms/step
# Run medium_noise, in large_noise at Fold 12/20: Accuracy: 0.29583333333333334, Precision: 0.3624217122354665, Recall: 0.29795436011365406
# Fold 13/20
# 38/38 [==============================] - 4s 83ms/step
# Run medium_noise, in origin at Fold 13/20: Accuracy: 0.44083333333333335, Precision: 0.4630171276028553, Recall: 0.44215960047795944
# 38/38 [==============================] - 4s 93ms/step
# Run medium_noise, in small_noise at Fold 13/20: Accuracy: 0.43666666666666665, Precision: 0.4758275192972395, Recall: 0.4380868176523939
# 38/38 [==============================] - 3s 91ms/step
# Run medium_noise, in large_noise at Fold 13/20: Accuracy: 0.2775, Precision: 0.3851469545193556, Recall: 0.2771175249301271
# Fold 14/20
# 38/38 [==============================] - 4s 90ms/step
# Run medium_noise, in origin at Fold 14/20: Accuracy: 0.44, Precision: 0.4491859133456174, Recall: 0.4407565605780862
# 38/38 [==============================] - 3s 90ms/step
# Run medium_noise, in small_noise at Fold 14/20: Accuracy: 0.435, Precision: 0.4540698155982099, Recall: 0.43654474000031335
# 38/38 [==============================] - 3s 92ms/step
# Run medium_noise, in large_noise at Fold 14/20: Accuracy: 0.3075, Precision: 0.4283620632254085, Recall: 0.3089632797852872
# Fold 15/20
# 38/38 [==============================] - 4s 90ms/step
# Run medium_noise, in origin at Fold 15/20: Accuracy: 0.4425, Precision: 0.43221618122909555, Recall: 0.4406139415939248
# 38/38 [==============================] - 3s 89ms/step
# Run medium_noise, in small_noise at Fold 15/20: Accuracy: 0.44, Precision: 0.43242651827967116, Recall: 0.438548837912608
# 38/38 [==============================] - 3s 90ms/step
# Run medium_noise, in large_noise at Fold 15/20: Accuracy: 0.3275, Precision: 0.3727979425722183, Recall: 0.32540210073554754
# Fold 16/20
# 38/38 [==============================] - 4s 99ms/step
# Run medium_noise, in origin at Fold 16/20: Accuracy: 0.415, Precision: 0.4288123299100096, Recall: 0.4174809824650011
# 38/38 [==============================] - 4s 99ms/step
# Run medium_noise, in small_noise at Fold 16/20: Accuracy: 0.4241666666666667, Precision: 0.4474861531961761, Recall: 0.42597062852011336
# 38/38 [==============================] - 4s 100ms/step
# Run medium_noise, in large_noise at Fold 16/20: Accuracy: 0.2966666666666667, Precision: 0.3674876566620642, Recall: 0.2999508562544834
# Fold 17/20
# 38/38 [==============================] - 4s 98ms/step
# Run medium_noise, in origin at Fold 17/20: Accuracy: 0.44583333333333336, Precision: 0.45146167349568184, Recall: 0.4461189971619038
# 38/38 [==============================] - 4s 97ms/step
# Run medium_noise, in small_noise at Fold 17/20: Accuracy: 0.44583333333333336, Precision: 0.4543976349523886, Recall: 0.4457299918497618
# 38/38 [==============================] - 4s 97ms/step
# Run medium_noise, in large_noise at Fold 17/20: Accuracy: 0.3258333333333333, Precision: 0.39183519686529983, Recall: 0.32454966091819976
# Fold 18/20
# 38/38 [==============================] - 4s 88ms/step
# Run medium_noise, in origin at Fold 18/20: Accuracy: 0.445, Precision: 0.45558484614691624, Recall: 0.44556011031828485
# 38/38 [==============================] - 3s 91ms/step
# Run medium_noise, in small_noise at Fold 18/20: Accuracy: 0.4425, Precision: 0.4572275117784458, Recall: 0.442923967017133
# 38/38 [==============================] - 4s 92ms/step
# Run medium_noise, in large_noise at Fold 18/20: Accuracy: 0.32083333333333336, Precision: 0.4061772393368659, Recall: 0.32402626744336577
# Fold 19/20
# 38/38 [==============================] - 5s 107ms/step
# Run medium_noise, in origin at Fold 19/20: Accuracy: 0.44083333333333335, Precision: 0.44032108334415304, Recall: 0.43876864199764165
# 38/38 [==============================] - 4s 107ms/step
# Run medium_noise, in small_noise at Fold 19/20: Accuracy: 0.43166666666666664, Precision: 0.4371806509627204, Recall: 0.42945159213027084
# 38/38 [==============================] - 4s 105ms/step
# Run medium_noise, in large_noise at Fold 19/20: Accuracy: 0.32666666666666666, Precision: 0.3830004213905031, Recall: 0.32375437889967296
# Fold 20/20
# 38/38 [==============================] - 4s 98ms/step
# Run medium_noise, in origin at Fold 20/20: Accuracy: 0.4375, Precision: 0.44141558690085175, Recall: 0.4376953090791088
# 38/38 [==============================] - 4s 97ms/step
# Run medium_noise, in small_noise at Fold 20/20: Accuracy: 0.43833333333333335, Precision: 0.45235776322461463, Recall: 0.4382186499717459
# 38/38 [==============================] - 4s 96ms/step
# Run medium_noise, in large_noise at Fold 20/20: Accuracy: 0.3283333333333333, Precision: 0.3943018293433067, Recall: 0.327944855999532
# Fold 1/20
# 38/38 [==============================] - 4s 91ms/step
# Run large_noise, in origin at Fold 1/20: Accuracy: 0.35333333333333333, Precision: 0.37187618814281126, Recall: 0.35684435035203854
# 38/38 [==============================] - 3s 90ms/step
# Run large_noise, in small_noise at Fold 1/20: Accuracy: 0.3625, Precision: 0.37580487220939324, Recall: 0.36564359583605327
# 38/38 [==============================] - 3s 90ms/step
# Run large_noise, in medium_noise at Fold 1/20: Accuracy: 0.3358333333333333, Precision: 0.35322944870291123, Recall: 0.33931787122049584
# Fold 2/20
# 38/38 [==============================] - 5s 107ms/step
# Run large_noise, in origin at Fold 2/20: Accuracy: 0.3308333333333333, Precision: 0.37087063333138837, Recall: 0.33381327290010077
# 38/38 [==============================] - 4s 108ms/step
# Run large_noise, in small_noise at Fold 2/20: Accuracy: 0.3475, Precision: 0.380739017370832, Recall: 0.34926507063035794
# 38/38 [==============================] - 4s 109ms/step
# Run large_noise, in medium_noise at Fold 2/20: Accuracy: 0.3125, Precision: 0.35913599313065814, Recall: 0.31559754754509495
# Fold 3/20
# 38/38 [==============================] - 5s 103ms/step
# Run large_noise, in origin at Fold 3/20: Accuracy: 0.3358333333333333, Precision: 0.40752452957104096, Recall: 0.3331423732352605
# 38/38 [==============================] - 4s 105ms/step
# Run large_noise, in small_noise at Fold 3/20: Accuracy: 0.3333333333333333, Precision: 0.368456141469128, Recall: 0.33018258538859335
# 38/38 [==============================] - 4s 105ms/step
# Run large_noise, in medium_noise at Fold 3/20: Accuracy: 0.31333333333333335, Precision: 0.3683732084199341, Recall: 0.31061314953142705
# Fold 4/20
# 38/38 [==============================] - 5s 106ms/step
# Run large_noise, in origin at Fold 4/20: Accuracy: 0.33916666666666667, Precision: 0.3828980733322029, Recall: 0.3454169506683763
# 38/38 [==============================] - 4s 106ms/step
# Run large_noise, in small_noise at Fold 4/20: Accuracy: 0.34833333333333333, Precision: 0.3723837812680224, Recall: 0.3528568035480679
# 38/38 [==============================] - 4s 106ms/step
# Run large_noise, in medium_noise at Fold 4/20: Accuracy: 0.3233333333333333, Precision: 0.36910293084445006, Recall: 0.3287686882363178
# Fold 5/20
# 38/38 [==============================] - 4s 102ms/step
# Run large_noise, in origin at Fold 5/20: Accuracy: 0.31833333333333336, Precision: 0.3422886308712707, Recall: 0.3250192516085081
# 38/38 [==============================] - 4s 102ms/step
# Run large_noise, in small_noise at Fold 5/20: Accuracy: 0.3358333333333333, Precision: 0.35581484350126635, Recall: 0.3424518279286584
# 38/38 [==============================] - 4s 103ms/step
# Run large_noise, in medium_noise at Fold 5/20: Accuracy: 0.30833333333333335, Precision: 0.3316479112852427, Recall: 0.31498477262028973
# Fold 6/20
# 38/38 [==============================] - 5s 110ms/step
# Run large_noise, in origin at Fold 6/20: Accuracy: 0.35583333333333333, Precision: 0.3814842322503414, Recall: 0.3586066462480122
# 38/38 [==============================] - 4s 109ms/step
# Run large_noise, in small_noise at Fold 6/20: Accuracy: 0.36916666666666664, Precision: 0.38986237724339545, Recall: 0.3709241371581252
# 38/38 [==============================] - 4s 109ms/step
# Run large_noise, in medium_noise at Fold 6/20: Accuracy: 0.33, Precision: 0.3554638412814902, Recall: 0.33267576705198654
# Fold 7/20
# 38/38 [==============================] - 4s 102ms/step
# Run large_noise, in origin at Fold 7/20: Accuracy: 0.31916666666666665, Precision: 0.3682189407141536, Recall: 0.32421356497412346
# 38/38 [==============================] - 4s 102ms/step
# Run large_noise, in small_noise at Fold 7/20: Accuracy: 0.3458333333333333, Precision: 0.3786116306078435, Recall: 0.34915807788747266
# 38/38 [==============================] - 4s 103ms/step
# Run large_noise, in medium_noise at Fold 7/20: Accuracy: 0.30666666666666664, Precision: 0.3518263407114187, Recall: 0.31134020957488107
# Fold 8/20
# 38/38 [==============================] - 4s 99ms/step
# Run large_noise, in origin at Fold 8/20: Accuracy: 0.3441666666666667, Precision: 0.3861239942375077, Recall: 0.34418020501608765
# 38/38 [==============================] - 4s 97ms/step
# Run large_noise, in small_noise at Fold 8/20: Accuracy: 0.34833333333333333, Precision: 0.3833190674277164, Recall: 0.34897638510055257
# 38/38 [==============================] - 4s 97ms/step
# Run large_noise, in medium_noise at Fold 8/20: Accuracy: 0.33, Precision: 0.3697943899473146, Recall: 0.32950905955172455
# Fold 9/20
# 38/38 [==============================] - 4s 98ms/step
# Run large_noise, in origin at Fold 9/20: Accuracy: 0.3591666666666667, Precision: 0.379263511178218, Recall: 0.3632143152293392
# 38/38 [==============================] - 4s 97ms/step
# Run large_noise, in small_noise at Fold 9/20: Accuracy: 0.3725, Precision: 0.3898489944642697, Recall: 0.3755398269075775
# 38/38 [==============================] - 4s 97ms/step
# Run large_noise, in medium_noise at Fold 9/20: Accuracy: 0.33666666666666667, Precision: 0.36156637169547184, Recall: 0.33987318443935854
# Fold 10/20
# 38/38 [==============================] - 4s 100ms/step
# Run large_noise, in origin at Fold 10/20: Accuracy: 0.35333333333333333, Precision: 0.4023811147348503, Recall: 0.3585358720305684
# 38/38 [==============================] - 4s 99ms/step
# Run large_noise, in small_noise at Fold 10/20: Accuracy: 0.355, Precision: 0.39286535228411223, Recall: 0.359544302041521
# 38/38 [==============================] - 4s 103ms/step
# Run large_noise, in medium_noise at Fold 10/20: Accuracy: 0.3275, Precision: 0.3734248248684452, Recall: 0.3322959194064851
# Fold 11/20
# 38/38 [==============================] - 5s 112ms/step
# Run large_noise, in origin at Fold 11/20: Accuracy: 0.345, Precision: 0.38264693842566644, Recall: 0.35057606975556155
# 38/38 [==============================] - 4s 110ms/step
# Run large_noise, in small_noise at Fold 11/20: Accuracy: 0.36, Precision: 0.3866538510542311, Recall: 0.3648544636462161
# 38/38 [==============================] - 4s 109ms/step
# Run large_noise, in medium_noise at Fold 11/20: Accuracy: 0.3258333333333333, Precision: 0.3650035732823221, Recall: 0.3308602258597917
# Fold 12/20
# 38/38 [==============================] - 4s 98ms/step
# Run large_noise, in origin at Fold 12/20: Accuracy: 0.3475, Precision: 0.3896562621792243, Recall: 0.3521355865416639
# 38/38 [==============================] - 4s 99ms/step
# Run large_noise, in small_noise at Fold 12/20: Accuracy: 0.36333333333333334, Precision: 0.3787996861702553, Recall: 0.3678803116038181
# 38/38 [==============================] - 4s 99ms/step
# Run large_noise, in medium_noise at Fold 12/20: Accuracy: 0.3358333333333333, Precision: 0.3688159351398992, Recall: 0.3407602318029298
# Fold 13/20
# 38/38 [==============================] - 4s 96ms/step
# Run large_noise, in origin at Fold 13/20: Accuracy: 0.36333333333333334, Precision: 0.3945530258220903, Recall: 0.36318528936233174
# 38/38 [==============================] - 4s 97ms/step
# Run large_noise, in small_noise at Fold 13/20: Accuracy: 0.37333333333333335, Precision: 0.3988239548569686, Recall: 0.3738660246463417
# 38/38 [==============================] - 4s 99ms/step
# Run large_noise, in medium_noise at Fold 13/20: Accuracy: 0.3525, Precision: 0.3810546118991068, Recall: 0.352170141851758
# Fold 14/20
# 38/38 [==============================] - 4s 102ms/step
# Run large_noise, in origin at Fold 14/20: Accuracy: 0.3333333333333333, Precision: 0.36532782700442146, Recall: 0.33504334091002824
# 38/38 [==============================] - 4s 101ms/step
# Run large_noise, in small_noise at Fold 14/20: Accuracy: 0.3641666666666667, Precision: 0.383776802873639, Recall: 0.3654817008798766
# 38/38 [==============================] - 4s 101ms/step
# Run large_noise, in medium_noise at Fold 14/20: Accuracy: 0.3175, Precision: 0.3467498392717766, Recall: 0.31971078164101707
# Fold 15/20
# 38/38 [==============================] - 4s 102ms/step
# Run large_noise, in origin at Fold 15/20: Accuracy: 0.3591666666666667, Precision: 0.3640418279334696, Recall: 0.3616069946714528
# 38/38 [==============================] - 4s 101ms/step
# Run large_noise, in small_noise at Fold 15/20: Accuracy: 0.37333333333333335, Precision: 0.3793190735711084, Recall: 0.37588041340215844
# 38/38 [==============================] - 4s 103ms/step
# Run large_noise, in medium_noise at Fold 15/20: Accuracy: 0.35333333333333333, Precision: 0.35436503366471717, Recall: 0.355540779141235
# Fold 16/20
# 38/38 [==============================] - 4s 102ms/step
# Run large_noise, in origin at Fold 16/20: Accuracy: 0.3408333333333333, Precision: 0.3827558348706796, Recall: 0.34232140362308383
# 38/38 [==============================] - 4s 102ms/step
# Run large_noise, in small_noise at Fold 16/20: Accuracy: 0.36, Precision: 0.38504577844915644, Recall: 0.361517301510299
# 38/38 [==============================] - 4s 102ms/step
# Run large_noise, in medium_noise at Fold 16/20: Accuracy: 0.32916666666666666, Precision: 0.35916015398826534, Recall: 0.33006202063836987
# Fold 17/20
# 38/38 [==============================] - 4s 103ms/step
# Run large_noise, in origin at Fold 17/20: Accuracy: 0.3416666666666667, Precision: 0.3735338308621557, Recall: 0.33887370728969146
# 38/38 [==============================] - 4s 103ms/step
# Run large_noise, in small_noise at Fold 17/20: Accuracy: 0.355, Precision: 0.376586136891745, Recall: 0.3525874983981776
# 38/38 [==============================] - 4s 104ms/step
# Run large_noise, in medium_noise at Fold 17/20: Accuracy: 0.32416666666666666, Precision: 0.3702071328697528, Recall: 0.3204253157711685
# Fold 18/20
# 38/38 [==============================] - 4s 101ms/step
# Run large_noise, in origin at Fold 18/20: Accuracy: 0.3433333333333333, Precision: 0.36512766946532954, Recall: 0.34435783704523515
# 38/38 [==============================] - 4s 101ms/step
# Run large_noise, in small_noise at Fold 18/20: Accuracy: 0.3525, Precision: 0.3591397334325007, Recall: 0.353072411042236
# 38/38 [==============================] - 4s 101ms/step
# Run large_noise, in medium_noise at Fold 18/20: Accuracy: 0.32416666666666666, Precision: 0.3514248508493097, Recall: 0.32512093687839805
# Fold 19/20
# 38/38 [==============================] - 4s 99ms/step
# Run large_noise, in origin at Fold 19/20: Accuracy: 0.3333333333333333, Precision: 0.3920954833459317, Recall: 0.33489650113560687
# 38/38 [==============================] - 4s 101ms/step
# Run large_noise, in small_noise at Fold 19/20: Accuracy: 0.3466666666666667, Precision: 0.3945371025961818, Recall: 0.34779437921056017
# 38/38 [==============================] - 4s 99ms/step
# Run large_noise, in medium_noise at Fold 19/20: Accuracy: 0.3225, Precision: 0.36670902699215846, Recall: 0.3233134179818044
# Fold 20/20
# 38/38 [==============================] - 4s 100ms/step
# Run large_noise, in origin at Fold 20/20: Accuracy: 0.3541666666666667, Precision: 0.3487912894015149, Recall: 0.3571514016564731
# 38/38 [==============================] - 4s 101ms/step
# Run large_noise, in small_noise at Fold 20/20: Accuracy: 0.3725, Precision: 0.3753714490580274, Recall: 0.3740274682283181
# 38/38 [==============================] - 4s 101ms/step
# Run large_noise, in medium_noise at Fold 20/20: Accuracy: 0.3425, Precision: 0.3403256016995412, Recall: 0.34496054737689763

# %%
all_performance_ViT[SMALL][1][ORIGIN]
# Out:
# {'accuracy': 0.4483333333333333,
#  'precision': 0.44926866062298976,
#  'recall': 0.45002361888428577}

# %%
def show_plt(dict, name):
    noise_levels = list(dict.keys())
    accuracy = [dict[noise]['accuracy'] for noise in noise_levels]
    precision = [dict[noise]['precision'] for noise in noise_levels]
    recall = [dict[noise]['recall'] for noise in noise_levels]

    plt.figure(figsize=(7, 6))
    plt.plot(noise_levels, accuracy, marker='o', label='Accuracy')
    plt.plot(noise_levels, precision, marker='o', label='Precision')
    plt.plot(noise_levels, recall, marker='o', label='Recall')

    plt.title(f'Model Performance under Different Noise Levels for {name} model')
    plt.xlabel('Noise Level')
    plt.ylabel('Score')
    plt.ylim(0, 1)
    plt.legend()
    plt.grid()
    plt.tight_layout()

    plt.show()

# %%
all_metrics = {}
for model_name in all_dataset:
    dataset_record = {}
    for dataset_name in all_dataset:
        if dataset_name == model_name:
            continue
        dataset_record[dataset_name] = {'accuracy':[], 'precision':[], 'recall':[]}
    all_metrics[model_name] = dataset_record
    for i in range(1, 21):
        for dataset in all_dataset:
            if model_name != dataset:
                dataset_record[dataset]['accuracy'].append(all_performance_ViT[model_name][i][dataset]['accuracy'])
                dataset_record[dataset]['precision'].append(all_performance_ViT[model_name][i][dataset]['precision'])
                dataset_record[dataset]['recall'].append(all_performance_ViT[model_name][i][dataset]['recall'])

# %%
for model_name in all_dataset:
    for dataset_name in all_dataset:
        if dataset_name == model_name:
            continue
        all_metrics[model_name][dataset_name]['accuracy'] = np.mean(all_metrics[model_name][dataset_name]['accuracy'])
        all_metrics[model_name][dataset_name]['precision'] = np.mean(all_metrics[model_name][dataset_name]['precision'])
        all_metrics[model_name][dataset_name]['recall'] = np.mean(all_metrics[model_name][dataset_name]['recall'])

all_metrics[ORIGIN]
# Out:
# {'small_noise': {'accuracy': 0.45370833333333344,
#   'precision': 0.46767015021634883,
#   'recall': 0.4539653569637818},
#  'medium_noise': {'accuracy': 0.4381666666666667,
#   'precision': 0.4490425364887625,
#   'recall': 0.4381621017508944},
#  'large_noise': {'accuracy': 0.3272083333333333,
#   'precision': 0.3981961514334794,
#   'recall': 0.3286956805285518}}

# %%
show_plt(all_metrics[ORIGIN], ORIGIN)
show_plt(all_metrics[SMALL], SMALL)
show_plt(all_metrics[MEDIUM], MEDIUM)
show_plt(all_metrics[LARGE], ORIGIN)
