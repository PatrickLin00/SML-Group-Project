# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import numpy as np
import pickle

import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from tensorflow import keras
from keras import models
from keras.models import Sequential
from keras.optimizers import Adam
import tensorflow as tf
import os
import copy

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 5
image_size = 72
num_heads = 4
projection_dim = 64
transformer_units = [
    projection_dim * 2,
    projection_dim
]
transformer_layers = 8
mlp_head_units = [2048, 1048] 

num_classes = 10
input_shape=(32,32,3)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation = tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images = images,
            sizes = [1, self.patch_size, self.patch_size, 1],
            strides = [1, self.patch_size, self.patch_size, 1],
            rates = [1, 1, 1, 1],
            padding = "VALID", 
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units = projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim = num_patches, output_dim = projection_dim
        )
    def call(self, patch):
        positions = tf.range(start = 0, limit = self.num_patches, delta = 1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_classifier(input_patch_size, input_data_augmentation):
    inputs = layers.Input(shape=input_shape)
    #augmented data
    augmented = input_data_augmentation(inputs)
    #create patches
    patches = Patches(input_patch_size)(augmented)
    # encode patches
    num_patches = (image_size // input_patch_size) ** 2
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer Block
    for _ in range(transformer_layers):
        # layer normalisation
        x1 = layers.LayerNormalization(epsilon= 1e-6)(encoded_patches)
        # Create a multi -  head attention layer
        attention_output = layers.MultiHeadAttention(
            num_heads = num_heads,
            key_dim = projection_dim,
            dropout = 0
        )(x1, x1)
        # Skip connection 1
        x2 = layers.Add()([attention_output, encoded_patches])
        #layer normalisation
        x3 = layers.LayerNormalization(epsilon = 1e-6)(x2)
        # MLP
        x2 = mlp(x3, hidden_units = transformer_units, dropout_rate = 0)
        # skip connection2
        encoded_patches =  layers.Add()([x3, x2])
    # Create a [batch_size, projection_dim] tensor
    representation = layers.LayerNormalization(epsilon = 1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0)(representation)

    # Add MLP 
    features = mlp(representation, hidden_units = mlp_head_units, dropout_rate = 0)
    #classify ouputs
    logits = layers.Dense(num_classes)(features)
    # Create the Keras Model
    model = keras.Model(inputs = inputs, outputs = logits)
    return model

# %%
def build_ViT_model(input_patch_size, input_data_augmentation):
    
    model = create_vit_classifier(input_patch_size, input_data_augmentation)
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )
    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy")
        ]
    )

    return model

# %%
def get_processed_dataset(dir):
    train_npy = np.load(dir)[:6000]
    label_npy = np.load('train_labels.npy')

    return train_npy, label_npy

# %%
patch_size_configs = [12, 18, 24]

train_accuracy_list = []
test_accuracy_list  = []
test_precision_list  = []
test_recall_list  = []

# %%
ORIGIN = 'origin_cifar10.npy'
SMALL = 'small_noise_cifar10.npy'
MEDIUM = 'medium_noise_cifar10.npy'
LARGE = 'large_noise_cifar10.npy'

# %%
outer_cv = KFold(n_splits=2, shuffle=True, random_state=42)
best_params = {}
performance_results = []

x_combined, y_combined = get_processed_dataset(MEDIUM)

data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size)
    ],
    name = "data_augmentation"
)
data_augmentation.layers[0].adapt(x_combined)


index_k_1 = 0

for outer_train_idx, outer_val_idx in outer_cv.split(x_combined):
    # print("outer_val_idx:", outer_val_idx)
    # print(type(outer_val_idx))
    index_k_1 = index_k_1 + 1
    print("index_k_1", index_k_1)
    
    X_outer_train, X_outer_val = x_combined[outer_train_idx], x_combined[outer_val_idx]
    y_outer_train, y_outer_val = y_combined[outer_train_idx], y_combined[outer_val_idx]

    best_score = -np.inf
    best_patch_size = None

    for patch_size in patch_size_configs:
        print("patch_size:", patch_size)
        inner_cv = KFold(n_splits=5, shuffle=True, random_state=42)
        scores = []
        
        for inner_train_idx, inner_val_idx in inner_cv.split(X_outer_train):
            X_inner_train, X_inner_val = X_outer_train[inner_train_idx], X_outer_train[inner_val_idx]
            y_inner_train, y_inner_val = y_outer_train[inner_train_idx], y_outer_train[inner_val_idx]
            
            model = build_ViT_model(patch_size, data_augmentation)
            history = model.fit(
                x=X_inner_train,
                y=y_inner_train,
                batch_size=batch_size,
                epochs=num_epochs,
                validation_data=(X_inner_val, y_inner_val)
            )
            
            score = model.evaluate(X_inner_val, y_inner_val, verbose=0)[1] # accuracy
            scores.append(score)

        mean_score = np.mean(scores)
        print("mean_score:", mean_score, "( patch_size", patch_size, ")")
        
        if mean_score > best_score:
            best_score = mean_score
            best_patch_size = patch_size

    best_params[index_k_1] = best_patch_size
    final_model = build_ViT_model(best_patch_size, data_augmentation)
    final_model.fit(X_outer_train, y_outer_train, epochs=5, batch_size=128, verbose=0)
    final_performance = final_model.evaluate(X_outer_val, y_outer_val)[1]
    performance_results.append(final_performance)
# Out:
# index_k_1 1
# patch_size: 12
# Epoch 1/5
# 19/19 [==============================] - 15s 515ms/step - loss: 2.5520 - accuracy: 0.2446 - val_loss: 2.0665 - val_accuracy: 0.2667
# Epoch 2/5
# 19/19 [==============================] - 9s 467ms/step - loss: 1.6844 - accuracy: 0.4050 - val_loss: 1.8477 - val_accuracy: 0.3617
# Epoch 3/5
# 19/19 [==============================] - 9s 473ms/step - loss: 1.2102 - accuracy: 0.5879 - val_loss: 1.8700 - val_accuracy: 0.3500
# Epoch 4/5
# 19/19 [==============================] - 9s 468ms/step - loss: 0.6193 - accuracy: 0.8108 - val_loss: 2.0286 - val_accuracy: 0.4067
# Epoch 5/5
# 19/19 [==============================] - 9s 465ms/step - loss: 0.2444 - accuracy: 0.9362 - val_loss: 2.1888 - val_accuracy: 0.4067
# Epoch 1/5
# 19/19 [==============================] - 14s 500ms/step - loss: 2.5873 - accuracy: 0.2304 - val_loss: 1.9771 - val_accuracy: 0.3000
# Epoch 2/5
# 19/19 [==============================] - 9s 464ms/step - loss: 1.6753 - accuracy: 0.4150 - val_loss: 1.7827 - val_accuracy: 0.3733
# Epoch 3/5
# 19/19 [==============================] - 9s 466ms/step - loss: 1.1299 - accuracy: 0.6154 - val_loss: 1.9866 - val_accuracy: 0.3483
# Epoch 4/5
# 19/19 [==============================] - 9s 468ms/step - loss: 0.6277 - accuracy: 0.8000 - val_loss: 2.1479 - val_accuracy: 0.3683
# Epoch 5/5
# 19/19 [==============================] - 9s 462ms/step - loss: 0.2314 - accuracy: 0.9425 - val_loss: 2.3219 - val_accuracy: 0.3900
# Epoch 1/5
# 19/19 [==============================] - 16s 536ms/step - loss: 2.5332 - accuracy: 0.2471 - val_loss: 1.8863 - val_accuracy: 0.3550
# Epoch 2/5
# 19/19 [==============================] - 9s 492ms/step - loss: 1.5779 - accuracy: 0.4479 - val_loss: 1.7506 - val_accuracy: 0.4117
# Epoch 3/5
# 19/19 [==============================] - 9s 486ms/step - loss: 1.0200 - accuracy: 0.6662 - val_loss: 1.7753 - val_accuracy: 0.3917
# Epoch 4/5
# 19/19 [==============================] - 9s 482ms/step - loss: 0.4514 - accuracy: 0.8683 - val_loss: 2.0004 - val_accuracy: 0.4250
# Epoch 5/5
# Epoch 5/5
# 19/19 [==============================] - 5s 256ms/step - loss: 0.2597 - accuracy: 0.9204 - val_loss: 2.4005 - val_accuracy: 0.3867
# Epoch 1/5
# 19/19 [==============================] - 11s 311ms/step - loss: 2.3568 - accuracy: 0.2229 - val_loss: 1.8359 - val_accuracy: 0.3283
# Epoch 2/5
# 19/19 [==============================] - 5s 265ms/step - loss: 1.6007 - accuracy: 0.4442 - val_loss: 1.8263 - val_accuracy: 0.3683
# Epoch 3/5
# 19/19 [==============================] - 5s 269ms/step - loss: 1.1291 - accuracy: 0.6254 - val_loss: 1.8531 - val_accuracy: 0.3800
# Epoch 4/5
# 19/19 [==============================] - 5s 273ms/step - loss: 0.6097 - accuracy: 0.8183 - val_loss: 2.1521 - val_accuracy: 0.3833
# Epoch 5/5
# 19/19 [==============================] - 5s 272ms/step - loss: 0.2903 - accuracy: 0.9192 - val_loss: 2.3171 - val_accuracy: 0.4067
# Epoch 1/5
# 19/19 [==============================] - 12s 319ms/step - loss: 2.2737 - accuracy: 0.2533 - val_loss: 1.9595 - val_accuracy: 0.3133
# Epoch 2/5
# 19/19 [==============================] - 5s 272ms/step - loss: 1.5636 - accuracy: 0.4487 - val_loss: 1.8916 - val_accuracy: 0.3333
# Epoch 3/5
# 19/19 [==============================] - 5s 275ms/step - loss: 1.0974 - accuracy: 0.6179 - val_loss: 1.9315 - val_accuracy: 0.3483
# Epoch 4/5
# 19/19 [==============================] - 5s 277ms/step - loss: 0.6260 - accuracy: 0.7983 - val_loss: 2.0929 - val_accuracy: 0.3733
# Epoch 5/5
# 19/19 [==============================] - 6s 320ms/step - loss: 0.2643 - accuracy: 0.9308 - val_loss: 2.4819 - val_accuracy: 0.3833
# Epoch 1/5
# 19/19 [==============================] - 13s 403ms/step - loss: 2.2721 - accuracy: 0.2537 - val_loss: 1.8490 - val_accuracy: 0.3250
# Epoch 2/5
# 19/19 [==============================] - 7s 344ms/step - loss: 1.5480 - accuracy: 0.4588 - val_loss: 1.7960 - val_accuracy: 0.3550
# Epoch 3/5
# 19/19 [==============================] - 7s 346ms/step - loss: 1.0478 - accuracy: 0.6383 - val_loss: 1.8269 - val_accuracy: 0.3967
# Epoch 4/5
# 19/19 [==============================] - 6s 341ms/step - loss: 0.5134 - accuracy: 0.8446 - val_loss: 2.0108 - val_accuracy: 0.3800
# Epoch 5/5
# 19/19 [==============================] - 6s 341ms/step - loss: 0.2500 - accuracy: 0.9275 - val_loss: 2.2544 - val_accuracy: 0.3717
# mean_score: 0.3843333303928375 ( patch_size 18 )
# patch_size: 24
# Epoch 1/5
# 19/19 [==============================] - 10s 246ms/step - loss: 2.2740 - accuracy: 0.2387 - val_loss: 1.9588 - val_accuracy: 0.2950
# Epoch 2/5
# 19/19 [==============================] - 4s 186ms/step - loss: 1.7134 - accuracy: 0.3883 - val_loss: 1.8268 - val_accuracy: 0.3400
# Epoch 3/5
# 19/19 [==============================] - 3s 184ms/step - loss: 1.3849 - accuracy: 0.5221 - val_loss: 1.8986 - val_accuracy: 0.3383
# Epoch 4/5
# 19/19 [==============================] - 3s 183ms/step - loss: 1.0000 - accuracy: 0.6475 - val_loss: 1.9564 - val_accuracy: 0.3400
# Epoch 5/5
# 19/19 [==============================] - 6s 324ms/step - loss: 0.4960 - accuracy: 0.8446 - val_loss: 2.1892 - val_accuracy: 0.3983
# mean_score: 0.3776666700839996 ( patch_size 24 )
# 94/94 [==============================] - 10s 101ms/step - loss: 2.4443 - accuracy: 0.3837
# index_k_1 2
# patch_size: 12
# Epoch 1/5
# 19/19 [==============================] - 23s 967ms/step - loss: 2.6007 - accuracy: 0.2379 - val_loss: 1.9347 - val_accuracy: 0.3017
# Epoch 2/5
# 19/19 [==============================] - 18s 927ms/step - loss: 1.6329 - accuracy: 0.4192 - val_loss: 1.8190 - val_accuracy: 0.3717
# Epoch 3/5
# 19/19 [==============================] - 18s 940ms/step - loss: 1.1451 - accuracy: 0.6096 - val_loss: 1.8796 - val_accuracy: 0.3500
# Epoch 4/5
# 19/19 [==============================] - 18s 937ms/step - loss: 0.5630 - accuracy: 0.8308 - val_loss: 2.1024 - val_accuracy: 0.3900
# Epoch 5/5
# 19/19 [==============================] - 18s 938ms/step - loss: 0.1952 - accuracy: 0.9467 - val_loss: 2.3962 - val_accuracy: 0.3833
# Epoch 1/5
# 19/19 [==============================] - 26s 1s/step - loss: 2.5187 - accuracy: 0.2350 - val_loss: 1.9269 - val_accuracy: 0.3183
# Epoch 2/5
# 19/19 [==============================] - 20s 1s/step - loss: 1.6396 - accuracy: 0.4175 - val_loss: 1.8063 - val_accuracy: 0.3500
# Epoch 3/5
# 19/19 [==============================] - 20s 1s/step - loss: 1.1455 - accuracy: 0.6054 - val_loss: 1.8457 - val_accuracy: 0.3883
# Epoch 4/5
# 19/19 [==============================] - 20s 1s/step - loss: 0.5987 - accuracy: 0.8150 - val_loss: 2.0152 - val_accuracy: 0.3800
# Epoch 5/5
# 19/19 [==============================] - 20s 1s/step - loss: 0.2276 - accuracy: 0.9408 - val_loss: 2.3068 - val_accuracy: 0.3983
# Epoch 1/5
# 19/19 [==============================] - 26s 1s/step - loss: 2.7601 - accuracy: 0.1979 - val_loss: 2.0203 - val_accuracy: 0.2683
# Epoch 2/5
# 19/19 [==============================] - 20s 1s/step - loss: 1.7872 - accuracy: 0.3629 - val_loss: 1.8353 - val_accuracy: 0.3467
# Epoch 3/5
# 19/19 [==============================] - 20s 1s/step - loss: 1.3648 - accuracy: 0.5296 - val_loss: 1.8218 - val_accuracy: 0.3800
# Epoch 4/5
# 19/19 [==============================] - 20s 1s/step - loss: 0.8516 - accuracy: 0.7133 - val_loss: 1.8532 - val_accuracy: 0.3867
# Epoch 5/5
# 19/19 [==============================] - 20s 1s/step - loss: 0.3713 - accuracy: 0.8933 - val_loss: 2.1791 - val_accuracy: 0.3600
# Epoch 1/5
# 19/19 [==============================] - 27s 1s/step - loss: 2.6518 - accuracy: 0.2283 - val_loss: 1.9010 - val_accuracy: 0.3117
# Epoch 2/5
# 19/19 [==============================] - 21s 1s/step - loss: 1.6866 - accuracy: 0.4004 - val_loss: 1.9239 - val_accuracy: 0.3217
# Epoch 3/5
# 19/19 [==============================] - 21s 1s/step - loss: 1.2434 - accuracy: 0.5796 - val_loss: 1.8277 - val_accuracy: 0.3483
# Epoch 4/5
# 19/19 [==============================] - 21s 1s/step - loss: 0.6012 - accuracy: 0.8358 - val_loss: 2.0697 - val_accuracy: 0.3567
# Epoch 5/5
# 19/19 [==============================] - 21s 1s/step - loss: 0.2399 - accuracy: 0.9337 - val_loss: 2.2862 - val_accuracy: 0.3733
# Epoch 1/5
# 19/19 [==============================] - 27s 1s/step - loss: 2.7437 - accuracy: 0.2400 - val_loss: 2.0759 - val_accuracy: 0.2900
# Epoch 2/5
# 19/19 [==============================] - 21s 1s/step - loss: 1.6830 - accuracy: 0.4200 - val_loss: 1.8627 - val_accuracy: 0.3500
# Epoch 3/5
# 19/19 [==============================] - 20s 1s/step - loss: 1.1611 - accuracy: 0.6067 - val_loss: 2.0015 - val_accuracy: 0.3483
# Epoch 4/5
# 19/19 [==============================] - 21s 1s/step - loss: 0.6281 - accuracy: 0.8150 - val_loss: 2.1085 - val_accuracy: 0.3700
# Epoch 5/5
# 19/19 [==============================] - 21s 1s/step - loss: 0.2553 - accuracy: 0.9350 - val_loss: 2.1750 - val_accuracy: 0.4133
# mean_score: 0.3856666684150696 ( patch_size 12 )
# patch_size: 18
# Epoch 1/5
# 19/19 [==============================] - 16s 581ms/step - loss: 2.4051 - accuracy: 0.2229 - val_loss: 1.9508 - val_accuracy: 0.2967
# Epoch 2/5
# 19/19 [==============================] - 10s 547ms/step - loss: 1.6226 - accuracy: 0.4221 - val_loss: 1.8086 - val_accuracy: 0.3350
# Epoch 3/5
# 19/19 [==============================] - 10s 546ms/step - loss: 1.1803 - accuracy: 0.6012 - val_loss: 1.8826 - val_accuracy: 0.3700
# Epoch 4/5
# 19/19 [==============================] - 10s 542ms/step - loss: 0.7085 - accuracy: 0.7829 - val_loss: 2.0536 - val_accuracy: 0.3783
# Epoch 5/5
# 19/19 [==============================] - 10s 551ms/step - loss: 0.3293 - accuracy: 0.9117 - val_loss: 2.3554 - val_accuracy: 0.3583
# Epoch 1/5
# 19/19 [==============================] - 18s 649ms/step - loss: 2.3505 - accuracy: 0.2592 - val_loss: 2.0462 - val_accuracy: 0.2733
# Epoch 2/5
# 19/19 [==============================] - 11s 606ms/step - loss: 1.6458 - accuracy: 0.4321 - val_loss: 1.8379 - val_accuracy: 0.3650
# Epoch 3/5
# 19/19 [==============================] - 11s 604ms/step - loss: 1.2078 - accuracy: 0.5896 - val_loss: 1.8251 - val_accuracy: 0.3600
# Epoch 4/5
# 19/19 [==============================] - 12s 621ms/step - loss: 0.6888 - accuracy: 0.7875 - val_loss: 2.0909 - val_accuracy: 0.3533
# Epoch 5/5
# 19/19 [==============================] - 12s 617ms/step - loss: 0.3185 - accuracy: 0.9033 - val_loss: 2.2421 - val_accuracy: 0.3867
# Epoch 1/5
# 19/19 [==============================] - 19s 685ms/step - loss: 2.3048 - accuracy: 0.2292 - val_loss: 1.8924 - val_accuracy: 0.3167
# Epoch 2/5
# 19/19 [==============================] - 12s 634ms/step - loss: 1.7028 - accuracy: 0.3929 - val_loss: 1.7707 - val_accuracy: 0.3817
# Epoch 3/5
# 19/19 [==============================] - 12s 629ms/step - loss: 1.2127 - accuracy: 0.5817 - val_loss: 1.8113 - val_accuracy: 0.3650
# Epoch 4/5
# 19/19 [==============================] - 12s 634ms/step - loss: 0.7206 - accuracy: 0.7646 - val_loss: 1.9647 - val_accuracy: 0.3600
# Epoch 5/5
# 19/19 [==============================] - 12s 629ms/step - loss: 0.3376 - accuracy: 0.9050 - val_loss: 2.2416 - val_accuracy: 0.3833
# Epoch 1/5
# 19/19 [==============================] - 17s 653ms/step - loss: 2.3135 - accuracy: 0.2408 - val_loss: 1.9171 - val_accuracy: 0.3200
# Epoch 2/5
# 19/19 [==============================] - 12s 609ms/step - loss: 1.6058 - accuracy: 0.4425 - val_loss: 1.8194 - val_accuracy: 0.3433
# Epoch 3/5
# 19/19 [==============================] - 12s 609ms/step - loss: 1.1552 - accuracy: 0.6033 - val_loss: 1.8768 - val_accuracy: 0.3850
# Epoch 4/5
# 19/19 [==============================] - 12s 629ms/step - loss: 0.6551 - accuracy: 0.7971 - val_loss: 2.2010 - val_accuracy: 0.3650
# Epoch 5/5
# 19/19 [==============================] - 12s 611ms/step - loss: 0.3022 - accuracy: 0.9179 - val_loss: 2.3836 - val_accuracy: 0.3650
# Epoch 1/5
# 19/19 [==============================] - 19s 722ms/step - loss: 2.3191 - accuracy: 0.2367 - val_loss: 1.9793 - val_accuracy: 0.3117
# Epoch 2/5
# 19/19 [==============================] - 12s 639ms/step - loss: 1.5962 - accuracy: 0.4417 - val_loss: 1.9247 - val_accuracy: 0.3417
# Epoch 3/5
# 19/19 [==============================] - 12s 633ms/step - loss: 1.1438 - accuracy: 0.6137 - val_loss: 1.9401 - val_accuracy: 0.3550
# Epoch 4/5
# 19/19 [==============================] - 12s 636ms/step - loss: 0.6582 - accuracy: 0.8000 - val_loss: 2.1397 - val_accuracy: 0.3767
# Epoch 5/5
# 19/19 [==============================] - 12s 640ms/step - loss: 0.3031 - accuracy: 0.9196 - val_loss: 2.4659 - val_accuracy: 0.3367
# mean_score: 0.3659999966621399 ( patch_size 18 )
# patch_size: 24
# Epoch 1/5
# 19/19 [==============================] - 16s 522ms/step - loss: 2.3004 - accuracy: 0.2379 - val_loss: 1.9841 - val_accuracy: 0.3283
# Epoch 2/5
# 19/19 [==============================] - 9s 477ms/step - loss: 1.7096 - accuracy: 0.3817 - val_loss: 1.8899 - val_accuracy: 0.3317
# Epoch 3/5
# 19/19 [==============================] - 9s 473ms/step - loss: 1.3542 - accuracy: 0.5133 - val_loss: 1.9283 - val_accuracy: 0.3550
# Epoch 4/5
# 19/19 [==============================] - 9s 469ms/step - loss: 0.9802 - accuracy: 0.6733 - val_loss: 1.9746 - val_accuracy: 0.3517
# Epoch 5/5
# 19/19 [==============================] - 9s 475ms/step - loss: 0.5818 - accuracy: 0.8163 - val_loss: 2.3213 - val_accuracy: 0.3950
# Epoch 1/5
# 19/19 [==============================] - 14s 488ms/step - loss: 2.2284 - accuracy: 0.2383 - val_loss: 1.9042 - val_accuracy: 0.3167
# Epoch 2/5
# 19/19 [==============================] - 8s 445ms/step - loss: 1.6687 - accuracy: 0.4108 - val_loss: 1.7423 - val_accuracy: 0.3767
# Epoch 3/5
# 19/19 [==============================] - 8s 441ms/step - loss: 1.2860 - accuracy: 0.5533 - val_loss: 1.8475 - val_accuracy: 0.3300
# Epoch 4/5
# 19/19 [==============================] - 8s 441ms/step - loss: 0.8878 - accuracy: 0.6917 - val_loss: 1.9799 - val_accuracy: 0.3683
# Epoch 5/5
# 19/19 [==============================] - 8s 443ms/step - loss: 0.5441 - accuracy: 0.8250 - val_loss: 2.2909 - val_accuracy: 0.3500
# Epoch 1/5
# 19/19 [==============================] - 15s 503ms/step - loss: 2.2222 - accuracy: 0.2358 - val_loss: 1.8836 - val_accuracy: 0.2983
# Epoch 2/5
# 19/19 [==============================] - 9s 458ms/step - loss: 1.6789 - accuracy: 0.4029 - val_loss: 1.7993 - val_accuracy: 0.3550
# Epoch 3/5
# 19/19 [==============================] - 9s 460ms/step - loss: 1.2996 - accuracy: 0.5350 - val_loss: 1.8266 - val_accuracy: 0.3833
# Epoch 4/5
# 19/19 [==============================] - 9s 473ms/step - loss: 0.8784 - accuracy: 0.7150 - val_loss: 2.0355 - val_accuracy: 0.3617
# Epoch 5/5
# 19/19 [==============================] - 9s 464ms/step - loss: 0.5224 - accuracy: 0.8396 - val_loss: 2.3901 - val_accuracy: 0.3383
# Epoch 1/5
# 19/19 [==============================] - 15s 502ms/step - loss: 2.1781 - accuracy: 0.2604 - val_loss: 1.8934 - val_accuracy: 0.3300
# Epoch 2/5
# 19/19 [==============================] - 9s 460ms/step - loss: 1.6460 - accuracy: 0.4062 - val_loss: 1.9332 - val_accuracy: 0.3117
# Epoch 3/5
# 19/19 [==============================] - 9s 454ms/step - loss: 1.3039 - accuracy: 0.5583 - val_loss: 1.9269 - val_accuracy: 0.3400
# Epoch 4/5
# 19/19 [==============================] - 9s 460ms/step - loss: 0.8840 - accuracy: 0.7033 - val_loss: 2.0470 - val_accuracy: 0.3600
# Epoch 5/5
# 19/19 [==============================] - 9s 459ms/step - loss: 0.5413 - accuracy: 0.8229 - val_loss: 2.2140 - val_accuracy: 0.3800
# Epoch 1/5
# 19/19 [==============================] - 14s 471ms/step - loss: 2.1903 - accuracy: 0.2500 - val_loss: 1.9060 - val_accuracy: 0.3267
# Epoch 2/5
# 19/19 [==============================] - 8s 432ms/step - loss: 1.6477 - accuracy: 0.4137 - val_loss: 1.8736 - val_accuracy: 0.3167
# Epoch 3/5
# 19/19 [==============================] - 8s 431ms/step - loss: 1.3265 - accuracy: 0.5300 - val_loss: 1.9468 - val_accuracy: 0.3517
# Epoch 4/5
# 19/19 [==============================] - 8s 435ms/step - loss: 0.9198 - accuracy: 0.6846 - val_loss: 2.1209 - val_accuracy: 0.3483
# Epoch 5/5
# 19/19 [==============================] - 8s 435ms/step - loss: 0.5098 - accuracy: 0.8367 - val_loss: 2.4765 - val_accuracy: 0.3483
# mean_score: 0.36233333349227903 ( patch_size 24 )
# 94/94 [==============================] - 14s 139ms/step - loss: 2.2651 - accuracy: 0.4170

# %%
average_performance = np.mean(performance_results)
print(f'Average Performance across all outer folds: {average_performance}')
print(performance_results)
print(f'Best Parameters for each fold: {best_params}')
# Out:
# Average Performance across all outer folds: 0.40033333003520966
# [0.38366666436195374, 0.4169999957084656]
# Best Parameters for each fold: {1: 12, 2: 12}
