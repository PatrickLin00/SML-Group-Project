# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
import numpy as np
import pickle
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from tensorflow import keras
from keras import models
from keras.models import Sequential
from keras.optimizers import Adam
import tensorflow as tf
import os
import copy
from sklearn.model_selection import train_test_split

# %%
# Function to load datasets
def get_dataset(obj_name):
    filename_labels = 'train_labels.npy'
    filename_origin = 'origin_cifar10.npy'
    filename_small_noise = 'small_noise_cifar10.npy'
    filename_medium_noise = 'medium_noise_cifar10.npy'
    filename_large_noise = 'large_noise_cifar10.npy'
    
    train_set = None
    match obj_name:
        case 'origin':
            train_set = np.load(filename_origin)
        case 'small_noise':
            train_set = np.load(filename_small_noise)
        case 'medium_noise':
            train_set = np.load(filename_medium_noise)
        case 'large_noise':
            train_set = np.load(filename_large_noise)
        case _:
            raise ValueError(f"Unknown obj_name: {obj_name}")
    label_set = np.load(filename_labels) if train_set.size > 0 else None

    if label_set is None or train_set is None:
        print("Run Noise_process.ipynb before running this file")
    return train_set, label_set

# %%
ORIGIN = 'origin'
SMALL = 'small_noise'
MEDIUM = 'medium_noise'
LARGE = 'large_noise'
all_dataset = [ORIGIN, SMALL, MEDIUM, LARGE]

# %%
# MLP: learning_rate, num_units, dropout_rate
best_config_origin_mlp = {'name': ORIGIN, 'num_units': 512}
best_config_small_mlp = {'name': SMALL, 'num_units': 256}
best_config_medium_mlp = {'name': MEDIUM, 'num_units': 512}
best_config_large_mlp = {'name': LARGE, 'num_units': 512}
best_config_mlp = [
    best_config_origin_mlp, best_config_small_mlp, best_config_medium_mlp, best_config_large_mlp
]

# %% [markdown]
# Build Model

# %%
# Function to build MLP model
def build_mlp_model(num_units, learning_rate=0.0005, dropout_rate=0, input_shape=(32, 32, 3), num_classes=10):
    model = Sequential([
        Input(shape=input_shape),
        Flatten(),
        Dense(num_units, activation='relu'),
        Dropout(dropout_rate),
        Dense(num_units, activation='relu'),
        Dropout(dropout_rate),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# Function to process dataset
def get_processed_dataset(model_name):
    train_set, label_set = get_dataset(model_name)
    X_combined_reshaped = train_set.reshape(-1, 32, 32, 3)
    X_combined_reshaped = X_combined_reshaped.astype('float32') / 255.0
    y_combined_categorical = to_categorical(label_set, num_classes=10)
    return X_combined_reshaped, y_combined_categorical

# %%
# Function to plot learning curves
def plot_learning_curves(all_history, model_name):
    train_loss = np.mean([h['loss'] for h in all_history], axis=0)
    val_loss = np.mean([h['val_loss'] for h in all_history], axis=0)
    train_accuracy = np.mean([h['accuracy'] for h in all_history], axis=0)
    val_accuracy = np.mean([h['val_accuracy'] for h in all_history], axis=0)

    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(train_loss, label='Train Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title(f'Loss Curve {model_name} MLP')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracy, label='Train Accuracy')
    plt.plot(val_accuracy, label='Validation Accuracy')
    plt.title(f'Accuracy Curve {model_name} MLP')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.show()

# %%
# Train and evaluate MLP models for all configurations
all_performance_mlp = {}
all_histories = {}

for config in best_config_mlp:
    model_name = config['name']
    model_performance = {}

    # Use 80% for cross validation and 20% for robustness test for other model
    x_processed, y_processed = get_processed_dataset(model_name)
    x_cv, _, y_cv, _ = train_test_split(x_processed, y_processed, test_size=0.2, random_state=42)

    # Cross Validation
    kf = KFold(n_splits=20, shuffle=True, random_state=42)
    all_history = []

    for fold, (train_index, val_index) in enumerate(kf.split(x_cv)):
        print(f'Fold {fold + 1}/{20}')

        model = build_mlp_model(config['num_units'])

        x_train, x_val = x_cv[train_index], x_cv[val_index]
        y_train, y_val = y_cv[train_index], y_cv[val_index]

        history = model.fit(x_train, y_train, epochs=5, batch_size=128, validation_data=(x_val, y_val), verbose=0)
        all_history.append(history.history)
        model_performance_fold = {}

        # Robustness Test
        for dataset_name in all_dataset:
            if dataset_name == model_name:
                # Skip robustness evaluation for the same dataset
                continue

            x_evaluated, y_evaluated = get_processed_dataset(dataset_name)
            _, x_test, _, y_test = train_test_split(x_evaluated, y_evaluated, test_size=0.2, random_state=42)

            y_pred = model.predict(x_test)
            y_pred_classes = np.argmax(y_pred, axis=1)
            y_true_classes = np.argmax(y_test, axis=1) 

            accuracy = accuracy_score(y_true_classes, y_pred_classes)
            precision = precision_score(y_true_classes, y_pred_classes, average='macro', zero_division=0)
            recall = recall_score(y_true_classes, y_pred_classes, average='macro')

            print(f"Run {model_name}, in {dataset_name} at Fold {fold + 1}/{20}: Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}")
            model_performance_fold[dataset_name] = {'accuracy': accuracy, 'precision': precision, 'recall': recall}
        
        model_performance[fold+1] = model_performance_fold

    all_performance_mlp[model_name] = model_performance

    # Plot learning curves for each model
    plot_learning_curves(all_history, model_name)
    all_histories[model_name] = all_history
# Out:
# Fold 1/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Run origin, in small_noise at Fold 1/20: Accuracy: 0.3425, Precision: 0.3887595657896531, Recall: 0.3422909679733187
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in medium_noise at Fold 1/20: Accuracy: 0.33666666666666667, Precision: 0.37812519094780395, Recall: 0.3366610645434153
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in large_noise at Fold 1/20: Accuracy: 0.22333333333333333, Precision: 0.28428184227425457, Recall: 0.22573770514673241
# Fold 2/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run origin, in small_noise at Fold 2/20: Accuracy: 0.3416666666666667, Precision: 0.428103913594977, Recall: 0.34003630691342557
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in medium_noise at Fold 2/20: Accuracy: 0.35583333333333333, Precision: 0.4087152219500575, Recall: 0.35479701446919576
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in large_noise at Fold 2/20: Accuracy: 0.23083333333333333, Precision: 0.39654207310347883, Recall: 0.23184487923032507
# Fold 3/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run origin, in small_noise at Fold 3/20: Accuracy: 0.3591666666666667, Precision: 0.3921963572534001, Recall: 0.3480033296229685
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in medium_noise at Fold 3/20: Accuracy: 0.35, Precision: 0.37242542628613917, Recall: 0.3403679570490919
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in large_noise at Fold 3/20: Accuracy: 0.23833333333333334, Precision: 0.35688941211904995, Recall: 0.232718346416541
# Fold 4/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Run origin, in small_noise at Fold 4/20: Accuracy: 0.37583333333333335, Precision: 0.37473934982989404, Recall: 0.3751066311850763
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in medium_noise at Fold 4/20: Accuracy: 0.36333333333333334, Precision: 0.3681032531742549, Recall: 0.36175189245782463
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run origin, in large_noise at Fold 4/20: Accuracy: 0.2725, Precision: 0.3253578032442827, Recall: 0.2716273572411377
# Fold 5/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run origin, in small_noise at Fold 5/20: Accuracy: 0.38416666666666666, Precision: 0.4034189195640083, Recall: 0.3773003213563641
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run origin, in medium_noise at Fold 5/20: Accuracy: 0.37666666666666665, Precision: 0.38708711274280005, Recall: 0.37211640739511037
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in large_noise at Fold 5/20: Accuracy: 0.2683333333333333, Precision: 0.31174336862313007, Recall: 0.25999138423600476
# Fold 6/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run origin, in small_noise at Fold 6/20: Accuracy: 0.37166666666666665, Precision: 0.4074785717005325, Recall: 0.370800804648557
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in medium_noise at Fold 6/20: Accuracy: 0.36333333333333334, Precision: 0.39552338001722476, Recall: 0.3629034374738502
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in large_noise at Fold 6/20: Accuracy: 0.2633333333333333, Precision: 0.3391896129411445, Recall: 0.26065031141788697
# Fold 7/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run origin, in small_noise at Fold 7/20: Accuracy: 0.36666666666666664, Precision: 0.4001731359753432, Recall: 0.36260488780440886
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run origin, in medium_noise at Fold 7/20: Accuracy: 0.3625, Precision: 0.379147357646585, Recall: 0.3588459409541576
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run origin, in large_noise at Fold 7/20: Accuracy: 0.23166666666666666, Precision: 0.31676260527176675, Recall: 0.22890071119006267
# Fold 8/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in small_noise at Fold 8/20: Accuracy: 0.3883333333333333, Precision: 0.39181635802831705, Recall: 0.3810030700569389
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run origin, in medium_noise at Fold 8/20: Accuracy: 0.3883333333333333, Precision: 0.3846496491202938, Recall: 0.3815230153290581
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run origin, in large_noise at Fold 8/20: Accuracy: 0.2725, Precision: 0.3356389128698305, Recall: 0.2649833220697259
# Fold 9/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run origin, in small_noise at Fold 9/20: Accuracy: 0.36, Precision: 0.412608512389426, Recall: 0.3621384138337712
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Run origin, in medium_noise at Fold 9/20: Accuracy: 0.3625, Precision: 0.4019670608584122, Recall: 0.364805724108856
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run origin, in large_noise at Fold 9/20: Accuracy: 0.22916666666666666, Precision: 0.39628569653679097, Recall: 0.2308408934715493
# Fold 10/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run origin, in small_noise at Fold 10/20: Accuracy: 0.3575, Precision: 0.37862656315025384, Recall: 0.3543671922894104
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run origin, in medium_noise at Fold 10/20: Accuracy: 0.36083333333333334, Precision: 0.36946267498632107, Recall: 0.35705349440537354
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run origin, in large_noise at Fold 10/20: Accuracy: 0.24083333333333334, Precision: 0.3492225445748153, Recall: 0.2346027005173652
# Fold 11/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run origin, in small_noise at Fold 11/20: Accuracy: 0.3591666666666667, Precision: 0.44724005422143487, Recall: 0.36028569324313614
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in medium_noise at Fold 11/20: Accuracy: 0.3516666666666667, Precision: 0.4220757881206569, Recall: 0.35323496137858695
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in large_noise at Fold 11/20: Accuracy: 0.2633333333333333, Precision: 0.2791242899877363, Recall: 0.26345645327406564
# Fold 12/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run origin, in small_noise at Fold 12/20: Accuracy: 0.3466666666666667, Precision: 0.39211705732431595, Recall: 0.3448996519324449
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in medium_noise at Fold 12/20: Accuracy: 0.3358333333333333, Precision: 0.3820293378924837, Recall: 0.3347985182589457
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run origin, in large_noise at Fold 12/20: Accuracy: 0.2025, Precision: 0.31226712312806254, Recall: 0.2018321790589661
# Fold 13/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run origin, in small_noise at Fold 13/20: Accuracy: 0.34, Precision: 0.42124185828475547, Recall: 0.33993618362723
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in medium_noise at Fold 13/20: Accuracy: 0.3283333333333333, Precision: 0.40573744397304967, Recall: 0.32885847150884
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in large_noise at Fold 13/20: Accuracy: 0.2225, Precision: 0.321506790812235, Recall: 0.22645579787444192
# Fold 14/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run origin, in small_noise at Fold 14/20: Accuracy: 0.36333333333333334, Precision: 0.40722257298962755, Recall: 0.36294905337845645
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in medium_noise at Fold 14/20: Accuracy: 0.36666666666666664, Precision: 0.38920279515312295, Recall: 0.36763164981665347
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in large_noise at Fold 14/20: Accuracy: 0.2475, Precision: 0.2908069775336571, Recall: 0.24880595358952026
# Fold 15/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run origin, in small_noise at Fold 15/20: Accuracy: 0.365, Precision: 0.3898993556280807, Recall: 0.36323909461945575
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in medium_noise at Fold 15/20: Accuracy: 0.37333333333333335, Precision: 0.382969489521351, Recall: 0.3728215608145232
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run origin, in large_noise at Fold 15/20: Accuracy: 0.24333333333333335, Precision: 0.3082658716956396, Recall: 0.24015088912561278
# Fold 16/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run origin, in small_noise at Fold 16/20: Accuracy: 0.36083333333333334, Precision: 0.4160697459989183, Recall: 0.3588128011511947
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in medium_noise at Fold 16/20: Accuracy: 0.3625, Precision: 0.41083848638071335, Recall: 0.3607448987514573
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run origin, in large_noise at Fold 16/20: Accuracy: 0.2608333333333333, Precision: 0.34252444830538875, Recall: 0.25413042651281414
# Fold 17/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run origin, in small_noise at Fold 17/20: Accuracy: 0.3591666666666667, Precision: 0.39527203453657256, Recall: 0.3481239768092384
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in medium_noise at Fold 17/20: Accuracy: 0.34833333333333333, Precision: 0.37538629939031226, Recall: 0.3374899071329064
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in large_noise at Fold 17/20: Accuracy: 0.2683333333333333, Precision: 0.3402453494686818, Recall: 0.2589883910243527
# Fold 18/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Run origin, in small_noise at Fold 18/20: Accuracy: 0.36916666666666664, Precision: 0.4039603049603131, Recall: 0.3721762652110847
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run origin, in medium_noise at Fold 18/20: Accuracy: 0.3475, Precision: 0.3668243339380223, Recall: 0.3508590592163916
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in large_noise at Fold 18/20: Accuracy: 0.25833333333333336, Precision: 0.3873065848505629, Recall: 0.2599342003120927
# Fold 19/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Run origin, in small_noise at Fold 19/20: Accuracy: 0.3675, Precision: 0.4064318465721519, Recall: 0.3714025499187622
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in medium_noise at Fold 19/20: Accuracy: 0.35583333333333333, Precision: 0.39154765965798954, Recall: 0.35938607867200345
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run origin, in large_noise at Fold 19/20: Accuracy: 0.24583333333333332, Precision: 0.3235690617107287, Recall: 0.24838147712027592
# Fold 20/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Run origin, in small_noise at Fold 20/20: Accuracy: 0.36916666666666664, Precision: 0.4202850094277797, Recall: 0.36617734072608793
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run origin, in medium_noise at Fold 20/20: Accuracy: 0.3616666666666667, Precision: 0.4019826884904633, Recall: 0.35918787943817426
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run origin, in large_noise at Fold 20/20: Accuracy: 0.27166666666666667, Precision: 0.2992783816383814, Recall: 0.27004658068534265
# Fold 1/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run small_noise, in origin at Fold 1/20: Accuracy: 0.3591666666666667, Precision: 0.4223670679981864, Recall: 0.3561566866810419
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 1/20: Accuracy: 0.35333333333333333, Precision: 0.41269775954497917, Recall: 0.3508951445508557
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step
# Run small_noise, in large_noise at Fold 1/20: Accuracy: 0.245, Precision: 0.3715845188698399, Recall: 0.24167744163230526
# Fold 2/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in origin at Fold 2/20: Accuracy: 0.3908333333333333, Precision: 0.41494166945900285, Recall: 0.3864431751250469
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 2/20: Accuracy: 0.38083333333333336, Precision: 0.39684403597622997, Recall: 0.37579406406661386
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Run small_noise, in large_noise at Fold 2/20: Accuracy: 0.24416666666666667, Precision: 0.2931843803388604, Recall: 0.24111870929365403
# Fold 3/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in origin at Fold 3/20: Accuracy: 0.34, Precision: 0.3605515690857982, Recall: 0.3401128730395127
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 3/20: Accuracy: 0.3275, Precision: 0.34676987319183605, Recall: 0.3271664773448119
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in large_noise at Fold 3/20: Accuracy: 0.2475, Precision: 0.3287391756740972, Recall: 0.243158771773547
# Fold 4/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in origin at Fold 4/20: Accuracy: 0.385, Precision: 0.3953900651497445, Recall: 0.37837283160219787
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 4/20: Accuracy: 0.3625, Precision: 0.36397261835087363, Recall: 0.3561481417747077
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in large_noise at Fold 4/20: Accuracy: 0.24333333333333335, Precision: 0.32838043811392087, Recall: 0.23335015748191873
# Fold 5/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run small_noise, in origin at Fold 5/20: Accuracy: 0.345, Precision: 0.45353304092432467, Recall: 0.34128388653841857
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 5/20: Accuracy: 0.32666666666666666, Precision: 0.4299427357235155, Recall: 0.32306472519129115
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in large_noise at Fold 5/20: Accuracy: 0.25666666666666665, Precision: 0.2637813614456753, Recall: 0.2524853022438137
# Fold 6/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in origin at Fold 6/20: Accuracy: 0.3825, Precision: 0.3957501547014649, Recall: 0.37413907324559503
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 6/20: Accuracy: 0.37, Precision: 0.37381711191203665, Recall: 0.362165151539691
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in large_noise at Fold 6/20: Accuracy: 0.265, Precision: 0.333440462258397, Recall: 0.25440221623132453
# Fold 7/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run small_noise, in origin at Fold 7/20: Accuracy: 0.345, Precision: 0.4079316190374458, Recall: 0.33483726152255994
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 7/20: Accuracy: 0.32666666666666666, Precision: 0.3952381832904023, Recall: 0.31865991856338205
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in large_noise at Fold 7/20: Accuracy: 0.25916666666666666, Precision: 0.28090785441728205, Recall: 0.24973461181412543
# Fold 8/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run small_noise, in origin at Fold 8/20: Accuracy: 0.36333333333333334, Precision: 0.3994284576673813, Recall: 0.3670805353575435
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in medium_noise at Fold 8/20: Accuracy: 0.3525, Precision: 0.38472382061483007, Recall: 0.35656633800981624
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in large_noise at Fold 8/20: Accuracy: 0.2075, Precision: 0.33868815744664643, Recall: 0.2134617248631987
# Fold 9/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run small_noise, in origin at Fold 9/20: Accuracy: 0.3441666666666667, Precision: 0.38581634857525626, Recall: 0.3496696906262492
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 9/20: Accuracy: 0.3258333333333333, Precision: 0.3583778812213739, Recall: 0.3320828918686325
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in large_noise at Fold 9/20: Accuracy: 0.24333333333333335, Precision: 0.31480779925080615, Recall: 0.2474059122773566
# Fold 10/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Run small_noise, in origin at Fold 10/20: Accuracy: 0.37833333333333335, Precision: 0.3893425504253737, Recall: 0.3740079970385792
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 10/20: Accuracy: 0.35083333333333333, Precision: 0.3644727274367221, Recall: 0.34707132640142957
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in large_noise at Fold 10/20: Accuracy: 0.26416666666666666, Precision: 0.3280517469971688, Recall: 0.2595454164970378
# Fold 11/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run small_noise, in origin at Fold 11/20: Accuracy: 0.3616666666666667, Precision: 0.4032777412875775, Recall: 0.35788410161442585
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in medium_noise at Fold 11/20: Accuracy: 0.3541666666666667, Precision: 0.38158927434013024, Recall: 0.3524054454879436
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in large_noise at Fold 11/20: Accuracy: 0.2608333333333333, Precision: 0.2896053123723828, Recall: 0.25528387058777624
# Fold 12/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run small_noise, in origin at Fold 12/20: Accuracy: 0.33916666666666667, Precision: 0.4313752156662919, Recall: 0.3400656024888892
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 12/20: Accuracy: 0.32416666666666666, Precision: 0.34916789246603563, Recall: 0.3236261368329533
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in large_noise at Fold 12/20: Accuracy: 0.28583333333333333, Precision: 0.3342146340141565, Recall: 0.2877519913149979
# Fold 13/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run small_noise, in origin at Fold 13/20: Accuracy: 0.3516666666666667, Precision: 0.3479308549357365, Recall: 0.3510033205311024
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 13/20: Accuracy: 0.3416666666666667, Precision: 0.36200543810015573, Recall: 0.34135391771088164
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in large_noise at Fold 13/20: Accuracy: 0.2791666666666667, Precision: 0.33680545763736186, Recall: 0.27786976040417455
# Fold 14/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in origin at Fold 14/20: Accuracy: 0.3541666666666667, Precision: 0.42377727629216333, Recall: 0.3571948371819779
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 14/20: Accuracy: 0.3416666666666667, Precision: 0.3876100403531074, Recall: 0.34402804164639095
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in large_noise at Fold 14/20: Accuracy: 0.2875, Precision: 0.37269020655217816, Recall: 0.28910544089906653
# Fold 15/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in origin at Fold 15/20: Accuracy: 0.32916666666666666, Precision: 0.3992841277589232, Recall: 0.3216980875425238
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 15/20: Accuracy: 0.32166666666666666, Precision: 0.4108502615882805, Recall: 0.31425903813700423
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in large_noise at Fold 15/20: Accuracy: 0.25583333333333336, Precision: 0.3355037043643713, Recall: 0.2438951052877361
# Fold 16/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in origin at Fold 16/20: Accuracy: 0.3525, Precision: 0.40902087330498427, Recall: 0.3531358840496276
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 16/20: Accuracy: 0.3325, Precision: 0.38963837916510796, Recall: 0.3332912930474095
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in large_noise at Fold 16/20: Accuracy: 0.2475, Precision: 0.34868589528979577, Recall: 0.24813474723507883
# Fold 17/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run small_noise, in origin at Fold 17/20: Accuracy: 0.345, Precision: 0.3710062908887857, Recall: 0.3520323120627837
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 17/20: Accuracy: 0.34833333333333333, Precision: 0.37998235163417415, Recall: 0.3551623320059945
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in large_noise at Fold 17/20: Accuracy: 0.2775, Precision: 0.3923960239416827, Recall: 0.28350423409800707
# Fold 18/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in origin at Fold 18/20: Accuracy: 0.375, Precision: 0.3889309487307301, Recall: 0.3696604100394815
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 18/20: Accuracy: 0.36833333333333335, Precision: 0.3793331546041997, Recall: 0.36307006849696605
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in large_noise at Fold 18/20: Accuracy: 0.25416666666666665, Precision: 0.3231636130310291, Recall: 0.2474101075171451
# Fold 19/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Run small_noise, in origin at Fold 19/20: Accuracy: 0.3325, Precision: 0.33561258315490317, Recall: 0.3330702932047073
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in medium_noise at Fold 19/20: Accuracy: 0.31, Precision: 0.31444983251574044, Recall: 0.3106506533751191
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run small_noise, in large_noise at Fold 19/20: Accuracy: 0.25666666666666665, Precision: 0.29058703407484904, Recall: 0.25407290923274706
# Fold 20/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run small_noise, in origin at Fold 20/20: Accuracy: 0.37333333333333335, Precision: 0.40721442328686797, Recall: 0.37056193429513257
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in medium_noise at Fold 20/20: Accuracy: 0.3491666666666667, Precision: 0.38949539424332874, Recall: 0.34759671183643176
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run small_noise, in large_noise at Fold 20/20: Accuracy: 0.2758333333333333, Precision: 0.371293853075941, Recall: 0.2703099866971643
# Fold 1/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Run medium_noise, in origin at Fold 1/20: Accuracy: 0.31666666666666665, Precision: 0.3902008379750731, Recall: 0.31362859559992945
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in small_noise at Fold 1/20: Accuracy: 0.32166666666666666, Precision: 0.3871565860437747, Recall: 0.31786738505905787
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in large_noise at Fold 1/20: Accuracy: 0.25583333333333336, Precision: 0.34626718861525607, Recall: 0.25170995900439525
# Fold 2/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Run medium_noise, in origin at Fold 2/20: Accuracy: 0.3575, Precision: 0.4100885507482556, Recall: 0.35069107433956365
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in small_noise at Fold 2/20: Accuracy: 0.3425, Precision: 0.41582473566673955, Recall: 0.3352460706451495
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in large_noise at Fold 2/20: Accuracy: 0.2225, Precision: 0.31543169713565666, Recall: 0.2167537183523919
# Fold 3/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run medium_noise, in origin at Fold 3/20: Accuracy: 0.36666666666666664, Precision: 0.41199002620073844, Recall: 0.3686847217508603
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run medium_noise, in small_noise at Fold 3/20: Accuracy: 0.3625, Precision: 0.4059475257504597, Recall: 0.36292428935594007
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in large_noise at Fold 3/20: Accuracy: 0.25, Precision: 0.35394963318601214, Recall: 0.24828770032473058
# Fold 4/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Run medium_noise, in origin at Fold 4/20: Accuracy: 0.36833333333333335, Precision: 0.38081746935996724, Recall: 0.35818892139548
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in small_noise at Fold 4/20: Accuracy: 0.37666666666666665, Precision: 0.3904554767359231, Recall: 0.3659330468352576
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in large_noise at Fold 4/20: Accuracy: 0.2683333333333333, Precision: 0.3164858827692528, Recall: 0.2608813120556673
# Fold 5/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run medium_noise, in origin at Fold 5/20: Accuracy: 0.37083333333333335, Precision: 0.3575263060952477, Recall: 0.3685569641117909
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run medium_noise, in small_noise at Fold 5/20: Accuracy: 0.35833333333333334, Precision: 0.35378444837146633, Recall: 0.35566983094282284
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in large_noise at Fold 5/20: Accuracy: 0.255, Precision: 0.3046995162869417, Recall: 0.2502422081602995
# Fold 6/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in origin at Fold 6/20: Accuracy: 0.37666666666666665, Precision: 0.390087826085387, Recall: 0.37604638984204203
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in small_noise at Fold 6/20: Accuracy: 0.37583333333333335, Precision: 0.3948115401461313, Recall: 0.37503314002381793
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in large_noise at Fold 6/20: Accuracy: 0.2425, Precision: 0.329606918519737, Recall: 0.24394824333122048
# Fold 7/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in origin at Fold 7/20: Accuracy: 0.3075, Precision: 0.41247887465553046, Recall: 0.3183877364958795
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in small_noise at Fold 7/20: Accuracy: 0.30666666666666664, Precision: 0.42305628234484116, Recall: 0.3174413828495258
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run medium_noise, in large_noise at Fold 7/20: Accuracy: 0.2225, Precision: 0.2561316313939212, Recall: 0.22953475084237795
# Fold 8/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in origin at Fold 8/20: Accuracy: 0.37833333333333335, Precision: 0.40843779730756113, Recall: 0.3677425545100932
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in small_noise at Fold 8/20: Accuracy: 0.36833333333333335, Precision: 0.4166548986448638, Recall: 0.35777430383421543
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in large_noise at Fold 8/20: Accuracy: 0.2608333333333333, Precision: 0.3264240689788283, Recall: 0.25037639354013713
# Fold 9/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in origin at Fold 9/20: Accuracy: 0.36, Precision: 0.39494256170789827, Recall: 0.3578160743456985
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in small_noise at Fold 9/20: Accuracy: 0.3591666666666667, Precision: 0.3944549334337187, Recall: 0.3566968782875194
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in large_noise at Fold 9/20: Accuracy: 0.2683333333333333, Precision: 0.3361566415165859, Recall: 0.2675891641029077
# Fold 10/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run medium_noise, in origin at Fold 10/20: Accuracy: 0.33916666666666667, Precision: 0.4053268851915342, Recall: 0.34113223288624905
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run medium_noise, in small_noise at Fold 10/20: Accuracy: 0.31833333333333336, Precision: 0.4113754318390711, Recall: 0.3204135304022923
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in large_noise at Fold 10/20: Accuracy: 0.2075, Precision: 0.3513884733516145, Recall: 0.21113322278311228
# Fold 11/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run medium_noise, in origin at Fold 11/20: Accuracy: 0.3725, Precision: 0.4006392147238536, Recall: 0.36856400206278617
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in small_noise at Fold 11/20: Accuracy: 0.3641666666666667, Precision: 0.3931034148951965, Recall: 0.35877251085932005
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in large_noise at Fold 11/20: Accuracy: 0.235, Precision: 0.3847514025375233, Recall: 0.23166291204496803
# Fold 12/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run medium_noise, in origin at Fold 12/20: Accuracy: 0.3416666666666667, Precision: 0.4088766623182879, Recall: 0.3446232151047184
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in small_noise at Fold 12/20: Accuracy: 0.34833333333333333, Precision: 0.41173085609924726, Recall: 0.3515230514265887
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in large_noise at Fold 12/20: Accuracy: 0.25166666666666665, Precision: 0.329990733610099, Recall: 0.25442639215365814
# Fold 13/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in origin at Fold 13/20: Accuracy: 0.3825, Precision: 0.41205705336941134, Recall: 0.37766383195532055
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in small_noise at Fold 13/20: Accuracy: 0.385, Precision: 0.4335434240489743, Recall: 0.37985558363277594
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in large_noise at Fold 13/20: Accuracy: 0.2816666666666667, Precision: 0.28449908980383753, Recall: 0.2735534390443749
# Fold 14/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run medium_noise, in origin at Fold 14/20: Accuracy: 0.3525, Precision: 0.4081025388077363, Recall: 0.3583136903013469
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in small_noise at Fold 14/20: Accuracy: 0.3491666666666667, Precision: 0.40926332440143137, Recall: 0.3532995399343963
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in large_noise at Fold 14/20: Accuracy: 0.25416666666666665, Precision: 0.3575784725934307, Recall: 0.2545258823220503
# Fold 15/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run medium_noise, in origin at Fold 15/20: Accuracy: 0.38666666666666666, Precision: 0.4024645412904321, Recall: 0.3823562460261428
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in small_noise at Fold 15/20: Accuracy: 0.38916666666666666, Precision: 0.3999299478300589, Recall: 0.38444980102187176
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in large_noise at Fold 15/20: Accuracy: 0.28, Precision: 0.2902517759333786, Recall: 0.27631670691136423
# Fold 16/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Run medium_noise, in origin at Fold 16/20: Accuracy: 0.355, Precision: 0.38478005828674106, Recall: 0.3552817227356284
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run medium_noise, in small_noise at Fold 16/20: Accuracy: 0.35083333333333333, Precision: 0.38459821014237294, Recall: 0.3500156873217669
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in large_noise at Fold 16/20: Accuracy: 0.23916666666666667, Precision: 0.4067593539641541, Recall: 0.239665367339612
# Fold 17/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Run medium_noise, in origin at Fold 17/20: Accuracy: 0.3516666666666667, Precision: 0.41689579972720836, Recall: 0.35481550727582417
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in small_noise at Fold 17/20: Accuracy: 0.3475, Precision: 0.4192143593634632, Recall: 0.3498387673490842
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in large_noise at Fold 17/20: Accuracy: 0.26916666666666667, Precision: 0.3604588005310956, Recall: 0.2708449813389754
# Fold 18/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run medium_noise, in origin at Fold 18/20: Accuracy: 0.3908333333333333, Precision: 0.4004425688278898, Recall: 0.3894673661268724
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in small_noise at Fold 18/20: Accuracy: 0.3858333333333333, Precision: 0.3998887444445048, Recall: 0.3843927400160635
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run medium_noise, in large_noise at Fold 18/20: Accuracy: 0.26916666666666667, Precision: 0.2736729736282383, Recall: 0.26820926670970885
# Fold 19/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run medium_noise, in origin at Fold 19/20: Accuracy: 0.38, Precision: 0.3763636549992478, Recall: 0.37334616178466584
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run medium_noise, in small_noise at Fold 19/20: Accuracy: 0.37583333333333335, Precision: 0.3762811403642226, Recall: 0.3682167643459464
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run medium_noise, in large_noise at Fold 19/20: Accuracy: 0.26, Precision: 0.31884684126526874, Recall: 0.25355228359211407
# Fold 20/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run medium_noise, in origin at Fold 20/20: Accuracy: 0.36, Precision: 0.3964319227425311, Recall: 0.3600774189578537
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run medium_noise, in small_noise at Fold 20/20: Accuracy: 0.3566666666666667, Precision: 0.3970020235196242, Recall: 0.35738386318913223
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run medium_noise, in large_noise at Fold 20/20: Accuracy: 0.245, Precision: 0.2681780874258809, Recall: 0.24564960363880775
# Fold 1/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run large_noise, in origin at Fold 1/20: Accuracy: 0.31333333333333335, Precision: 0.3878143921266498, Recall: 0.31488325863524824
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in small_noise at Fold 1/20: Accuracy: 0.31666666666666665, Precision: 0.38855714008653386, Recall: 0.3182508859232146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in medium_noise at Fold 1/20: Accuracy: 0.3075, Precision: 0.36552964953871914, Recall: 0.30910605247123296
# Fold 2/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run large_noise, in origin at Fold 2/20: Accuracy: 0.2925, Precision: 0.34571843279488246, Recall: 0.2951570506624302
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in small_noise at Fold 2/20: Accuracy: 0.3025, Precision: 0.36250029092084024, Recall: 0.304667440309629
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in medium_noise at Fold 2/20: Accuracy: 0.2791666666666667, Precision: 0.3302701492723399, Recall: 0.28147310120486246
# Fold 3/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run large_noise, in origin at Fold 3/20: Accuracy: 0.3125, Precision: 0.3536387745388741, Recall: 0.3108733442190333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in small_noise at Fold 3/20: Accuracy: 0.3175, Precision: 0.3629508683858649, Recall: 0.3156765344947364
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in medium_noise at Fold 3/20: Accuracy: 0.30583333333333335, Precision: 0.3420978435325346, Recall: 0.3039607900696699
# Fold 4/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run large_noise, in origin at Fold 4/20: Accuracy: 0.325, Precision: 0.364977298080961, Recall: 0.3214814650223272
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in small_noise at Fold 4/20: Accuracy: 0.33, Precision: 0.3690668411067257, Recall: 0.3264493725385398
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in medium_noise at Fold 4/20: Accuracy: 0.30916666666666665, Precision: 0.3427891289769905, Recall: 0.3066121871250832
# Fold 5/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Run large_noise, in origin at Fold 5/20: Accuracy: 0.35, Precision: 0.38988825881971023, Recall: 0.34242358746632884
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in small_noise at Fold 5/20: Accuracy: 0.35333333333333333, Precision: 0.3874598169564961, Recall: 0.34624626334117864
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in medium_noise at Fold 5/20: Accuracy: 0.3308333333333333, Precision: 0.3390771990014134, Recall: 0.3230657590014996
# Fold 6/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run large_noise, in origin at Fold 6/20: Accuracy: 0.32, Precision: 0.32921305886853924, Recall: 0.3208596148263429
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in small_noise at Fold 6/20: Accuracy: 0.31833333333333336, Precision: 0.32365716578148956, Recall: 0.319494844850556
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in medium_noise at Fold 6/20: Accuracy: 0.3025, Precision: 0.29625278869079763, Recall: 0.30286796075454886
# Fold 7/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run large_noise, in origin at Fold 7/20: Accuracy: 0.31666666666666665, Precision: 0.38794264784415483, Recall: 0.31542399915240743
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in small_noise at Fold 7/20: Accuracy: 0.3283333333333333, Precision: 0.3992069854822494, Recall: 0.326853910557632
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in medium_noise at Fold 7/20: Accuracy: 0.2925, Precision: 0.36006067723171353, Recall: 0.2906153714745093
# Fold 8/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run large_noise, in origin at Fold 8/20: Accuracy: 0.2941666666666667, Precision: 0.34175009405970586, Recall: 0.28884441700524977
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in small_noise at Fold 8/20: Accuracy: 0.295, Precision: 0.3643185252676284, Recall: 0.28914238139654497
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in medium_noise at Fold 8/20: Accuracy: 0.2758333333333333, Precision: 0.33222184643762526, Recall: 0.27057253080989263
# Fold 9/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run large_noise, in origin at Fold 9/20: Accuracy: 0.315, Precision: 0.361664670958621, Recall: 0.30877932918224005
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in small_noise at Fold 9/20: Accuracy: 0.31916666666666665, Precision: 0.3729833851048098, Recall: 0.3130082039429497
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in medium_noise at Fold 9/20: Accuracy: 0.2966666666666667, Precision: 0.34456607151794916, Recall: 0.2911745585537037
# Fold 10/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run large_noise, in origin at Fold 10/20: Accuracy: 0.2783333333333333, Precision: 0.3818874945599303, Recall: 0.28189210527865655
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in small_noise at Fold 10/20: Accuracy: 0.2841666666666667, Precision: 0.3927723078264634, Recall: 0.28784803123675634
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in medium_noise at Fold 10/20: Accuracy: 0.26416666666666666, Precision: 0.3489957644915186, Recall: 0.2678675623443126
# Fold 11/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in origin at Fold 11/20: Accuracy: 0.3358333333333333, Precision: 0.3602999862124533, Recall: 0.33267704409321947
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in small_noise at Fold 11/20: Accuracy: 0.3408333333333333, Precision: 0.3689936834367053, Recall: 0.33798354049536805
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in medium_noise at Fold 11/20: Accuracy: 0.31916666666666665, Precision: 0.34203406401990455, Recall: 0.3166603353782057
# Fold 12/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in origin at Fold 12/20: Accuracy: 0.305, Precision: 0.3984706108535002, Recall: 0.30909760196816205
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in small_noise at Fold 12/20: Accuracy: 0.31, Precision: 0.3997349586117189, Recall: 0.3138627419497722
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in medium_noise at Fold 12/20: Accuracy: 0.29583333333333334, Precision: 0.3535185470866787, Recall: 0.30043979670538257
# Fold 13/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Run large_noise, in origin at Fold 13/20: Accuracy: 0.33666666666666667, Precision: 0.3762556952598327, Recall: 0.33086157247321585
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in small_noise at Fold 13/20: Accuracy: 0.3383333333333333, Precision: 0.38156118370000136, Recall: 0.33264558337756567
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in medium_noise at Fold 13/20: Accuracy: 0.32916666666666666, Precision: 0.3548224136880124, Recall: 0.322760155773973
# Fold 14/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in origin at Fold 14/20: Accuracy: 0.31833333333333336, Precision: 0.351789501717804, Recall: 0.31592249406206663
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in small_noise at Fold 14/20: Accuracy: 0.31833333333333336, Precision: 0.33777413722156807, Recall: 0.31590460037383394
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in medium_noise at Fold 14/20: Accuracy: 0.30416666666666664, Precision: 0.3317309771850645, Recall: 0.3016562747618385
# Fold 15/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in origin at Fold 15/20: Accuracy: 0.3258333333333333, Precision: 0.3842769435419684, Recall: 0.3201461351716326
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Run large_noise, in small_noise at Fold 15/20: Accuracy: 0.3333333333333333, Precision: 0.3921092169702744, Recall: 0.32742705936902694
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Run large_noise, in medium_noise at Fold 15/20: Accuracy: 0.31166666666666665, Precision: 0.3562278620533228, Recall: 0.3060574861395053
# Fold 16/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in origin at Fold 16/20: Accuracy: 0.33, Precision: 0.35452371609308236, Recall: 0.3245564941199797
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Run large_noise, in small_noise at Fold 16/20: Accuracy: 0.3333333333333333, Precision: 0.3559785066431688, Recall: 0.32819816625280884
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Run large_noise, in medium_noise at Fold 16/20: Accuracy: 0.31166666666666665, Precision: 0.344195778155438, Recall: 0.30590380400734124
# Fold 17/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run large_noise, in origin at Fold 17/20: Accuracy: 0.32666666666666666, Precision: 0.3762580921049816, Recall: 0.32009210500872254
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in small_noise at Fold 17/20: Accuracy: 0.3233333333333333, Precision: 0.3646873663520555, Recall: 0.31602269037766456
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in medium_noise at Fold 17/20: Accuracy: 0.3075, Precision: 0.3479430786911745, Recall: 0.3004545012589965
# Fold 18/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in origin at Fold 18/20: Accuracy: 0.30583333333333335, Precision: 0.32113388414800326, Recall: 0.3013288334117369
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in small_noise at Fold 18/20: Accuracy: 0.3125, Precision: 0.3280515014374005, Recall: 0.3081244276848182
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in medium_noise at Fold 18/20: Accuracy: 0.2833333333333333, Precision: 0.3039801152875106, Recall: 0.2791077087982025
# Fold 19/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run large_noise, in origin at Fold 19/20: Accuracy: 0.30916666666666665, Precision: 0.3830060147258327, Recall: 0.3111462977209477
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in small_noise at Fold 19/20: Accuracy: 0.31333333333333335, Precision: 0.38134942013991224, Recall: 0.31481781603314396
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Run large_noise, in medium_noise at Fold 19/20: Accuracy: 0.31, Precision: 0.369744920174087, Recall: 0.3119923183669683
# Fold 20/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Run large_noise, in origin at Fold 20/20: Accuracy: 0.3308333333333333, Precision: 0.386846211688053, Recall: 0.3328726705252497
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in small_noise at Fold 20/20: Accuracy: 0.3333333333333333, Precision: 0.38855815817629763, Recall: 0.335734951746853
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Run large_noise, in medium_noise at Fold 20/20: Accuracy: 0.31583333333333335, Precision: 0.36893894367434543, Recall: 0.31731228302525283

# %%
all_performance_mlp[SMALL][1][ORIGIN]
# Out:
# {'accuracy': 0.3591666666666667,
#  'precision': 0.4223670679981864,
#  'recall': 0.3561566866810419}

# %%
def show_plt(dict, name):
    noise_levels = list(dict.keys())
    accuracy = [dict[noise]['accuracy'] for noise in noise_levels]
    precision = [dict[noise]['precision'] for noise in noise_levels]
    recall = [dict[noise]['recall'] for noise in noise_levels]

    plt.figure(figsize=(10, 6))
    plt.plot(noise_levels, accuracy, marker='o', label='Accuracy')
    plt.plot(noise_levels, precision, marker='o', label='Precision')
    plt.plot(noise_levels, recall, marker='o', label='Recall')

    plt.title('Model Performance under Different Noise Levels')
    plt.xlabel('Noise Level')
    plt.ylabel('Score')
    plt.ylim(0, 1)  
    plt.legend()
    plt.grid()
    plt.tight_layout()

    plt.show()

# %%
all_metrics = {}
for model_name in all_dataset:
    dataset_record = {}
    for dataset_name in all_dataset:
        if dataset_name == model_name:
            continue
        dataset_record[dataset_name] = {'accuracy':[], 'precision':[], 'recall':[]}
    all_metrics[model_name] = dataset_record
    for i in range(1, 21):
        for dataset in all_dataset:
            if model_name != dataset:
                dataset_record[dataset]['accuracy'].append(all_performance_mlp[model_name][i][dataset]['accuracy'])
                dataset_record[dataset]['precision'].append(all_performance_mlp[model_name][i][dataset]['precision'])
                dataset_record[dataset]['recall'].append(all_performance_mlp[model_name][i][dataset]['recall'])

# %%
for model_name in all_dataset:
    for dataset_name in all_dataset:
        if dataset_name == model_name:
            continue
        all_metrics[model_name][dataset_name]['accuracy'] = np.mean(all_metrics[model_name][dataset_name]['accuracy'])
        all_metrics[model_name][dataset_name]['precision'] = np.mean(all_metrics[model_name][dataset_name]['precision'])
        all_metrics[model_name][dataset_name]['recall'] = np.mean(all_metrics[model_name][dataset_name]['recall'])

all_metrics[ORIGIN]
# Out:
# {'small_noise': {'accuracy': 0.362375,
#   'precision': 0.4038830543609877,
#   'recall': 0.3600827268150665},
#  'medium_noise': {'accuracy': 0.3575833333333333,
#   'precision': 0.38869003251240286,
#   'recall': 0.3557919466587208},
#  'large_noise': {'accuracy': 0.24775,
#   'precision': 0.33084043753448095,
#   'recall': 0.24570399797574077}}

# %%
show_plt(all_metrics[ORIGIN], ORIGIN)
show_plt(all_metrics[SMALL], SMALL)
show_plt(all_metrics[MEDIUM], MEDIUM)
show_plt(all_metrics[LARGE], ORIGIN)
