# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import numpy as np
import pickle
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from tensorflow import keras
from keras import models
from keras.models import Sequential
from keras.optimizers import Adam
import tensorflow as tf
import os
import copy

# %%
# Run Noise_process before run this file
def get_dataset(obj_name):
    filename_labels = 'train_labels.npy'
    filename_origin = 'origin_cifar10.npy'
    filename_small_noise = 'small_noise_cifar10.npy'
    filename_medium_noise = 'medium_noise_cifar10.npy'
    filename_large_noise = 'large_noise_cifar10.npy'
    
    train_set = None
    match obj_name:
        case 'origin':
            train_set = np.load(filename_origin)
        case 'small_noise':
            train_set = np.load(filename_small_noise)
        case 'medium_noise':
            train_set = np.load(filename_medium_noise)
        case 'large_noise':
            train_set = np.load(filename_large_noise)
        case _:
            raise ValueError(f"Unknown obj_name: {obj_name}")
    label_set = np.load(filename_labels) if train_set.size > 0 else None

    if label_set is None or train_set is None:
        print("Run Noise_process.ipynb before run this file")
    return train_set, label_set

# %%
def build_simple_cnn(num_filter, learning_rate=0.0005, filter_size=(3,3), input_shape=(32, 32, 3), num_classes=10):
    model = models.Sequential()
    model.add(layers.Input(shape=input_shape))  
    model.add(layers.Conv2D(num_filter, filter_size, activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(num_classes, activation='softmax'))
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def get_processed_dataset(model_name):
    train_set, label_set = get_dataset(model_name)

    X_combined_reshaped = train_set.reshape(-1, 32, 32, 3)
    X_combined_reshaped = X_combined_reshaped.astype('float32') / 255.0
    y_combined_categorical = to_categorical(label_set, num_classes=10)

    return X_combined_reshaped, y_combined_categorical

# %%
ORIGIN='origin'
SMALL='small_noise'
MEDIUM='medium_noise'
LARGE='large_noise'
all_dataset = [ORIGIN, SMALL, MEDIUM, LARGE]

batch_size = 128
num_epochs = 5

# %%
def get_processed_dataset(model_name):
    train_set, label_set = get_dataset(model_name)

    X_combined_reshaped = train_set.reshape(-1, 32, 32, 3)
    X_combined_reshaped = X_combined_reshaped.astype('float32') / 255.0
    y_combined_categorical = to_categorical(label_set, num_classes=10)

    return X_combined_reshaped, y_combined_categorical

# %%
ORIGIN='origin'
SMALL='small_noise'
MEDIUM='medium_noise'
LARGE='large_noise'
all_dataset = [ORIGIN, SMALL, MEDIUM, LARGE]

# %%
num_filter_configs = [8, 16, 32, 64, 128]

# %%
outer_cv = KFold(n_splits=5, shuffle=True, random_state=42)
best_params = {}
performance_results = []

x_combined, y_combined = get_processed_dataset(ORIGIN)

for outer_train_idx, outer_val_idx in outer_cv.split(x_combined):
    X_outer_train, X_outer_val = x_combined[outer_train_idx], x_combined[outer_val_idx]
    y_outer_train, y_outer_val = y_combined[outer_train_idx], y_combined[outer_val_idx]

    best_score = -np.inf
    best_num_filter = None

    for num_filter in num_filter_configs:
        inner_cv = KFold(n_splits=5, shuffle=True, random_state=42)
        scores = []
        
        for inner_train_idx, inner_val_idx in inner_cv.split(X_outer_train):
            X_inner_train, X_inner_val = X_outer_train[inner_train_idx], X_outer_train[inner_val_idx]
            y_inner_train, y_inner_val = y_outer_train[inner_train_idx], y_outer_train[inner_val_idx]
            
            model = build_simple_cnn(num_filter)
            history = model.fit(
                x=X_inner_train,
                y=y_inner_train,
                batch_size=batch_size,
                epochs=num_epochs,
                validation_data=(X_inner_val, y_inner_val)
            )
            
            score = model.evaluate(X_inner_val, y_inner_val, verbose=0)[0] 
            scores.append(score)

        mean_score = np.mean(scores)
        
        if mean_score > best_score:
            best_score = mean_score
            best_num_filter = num_filter

    best_params[outer_val_idx[0]] = best_num_filter
    final_model = build_simple_cnn(best_num_filter)
    final_model.fit(X_outer_train, y_outer_train, epochs=5, batch_size=128, verbose=0)
    final_performance = final_model.evaluate(X_outer_val, y_outer_val)[0]
    performance_results.append(final_performance)

average_performance = np.mean(performance_results)
print(f'Average Performance across all outer folds: {average_performance}')
print(f'Best Parameters for each fold: {best_params}')
# Out:
# Epoch 1/5
# 30/30 [==============================] - 1s 21ms/step - loss: 2.0978 - accuracy: 0.2740 - val_loss: 2.1699 - val_accuracy: 0.2104
# Epoch 2/5
# 30/30 [==============================] - 1s 18ms/step - loss: 1.5257 - accuracy: 0.4648 - val_loss: 2.1172 - val_accuracy: 0.2125
# Epoch 3/5
# 30/30 [==============================] - 0s 17ms/step - loss: 1.2529 - accuracy: 0.5742 - val_loss: 2.0560 - val_accuracy: 0.2854
# Epoch 4/5
# 30/30 [==============================] - 0s 16ms/step - loss: 1.0537 - accuracy: 0.6526 - val_loss: 1.9870 - val_accuracy: 0.3052
# Epoch 5/5
# 30/30 [==============================] - 0s 16ms/step - loss: 0.8663 - accuracy: 0.7383 - val_loss: 1.9263 - val_accuracy: 0.3271
# Epoch 1/5
# 30/30 [==============================] - 1s 18ms/step - loss: 2.1645 - accuracy: 0.2326 - val_loss: 2.2142 - val_accuracy: 0.1937
# Epoch 2/5
# 30/30 [==============================] - 1s 18ms/step - loss: 1.7377 - accuracy: 0.3841 - val_loss: 2.1214 - val_accuracy: 0.2375
# Epoch 3/5
# 30/30 [==============================] - 0s 16ms/step - loss: 1.4306 - accuracy: 0.5068 - val_loss: 2.1675 - val_accuracy: 0.2365
# Epoch 4/5
# 30/30 [==============================] - 0s 16ms/step - loss: 1.1427 - accuracy: 0.6112 - val_loss: 2.1259 - val_accuracy: 0.2667
# Epoch 5/5
# 30/30 [==============================] - 0s 15ms/step - loss: 0.9032 - accuracy: 0.7115 - val_loss: 2.0865 - val_accuracy: 0.2781
# Epoch 1/5
# 30/30 [==============================] - 1s 18ms/step - loss: 2.0803 - accuracy: 0.2859 - val_loss: 2.1714 - val_accuracy: 0.2406
# Epoch 2/5
# 30/30 [==============================] - 1s 18ms/step - loss: 1.5211 - accuracy: 0.4711 - val_loss: 2.1070 - val_accuracy: 0.3240
# Epoch 3/5
# 30/30 [==============================] - 0s 16ms/step - loss: 1.2888 - accuracy: 0.5654 - val_loss: 2.0550 - val_accuracy: 0.3792
# Epoch 4/5
# 30/30 [==============================] - 0s 17ms/step - loss: 1.1043 - accuracy: 0.6383 - val_loss: 2.0132 - val_accuracy: 0.3635
# Epoch 5/5
# 30/30 [==============================] - 0s 15ms/step - loss: 0.9383 - accuracy: 0.7055 - val_loss: 1.9523 - val_accuracy: 0.3958
# Epoch 1/5
# 30/30 [==============================] - 1s 25ms/step - loss: 2.0630 - accuracy: 0.2753 - val_loss: 2.1540 - val_accuracy: 0.3000
# Epoch 2/5
# 30/30 [==============================] - 1s 18ms/step - loss: 1.5216 - accuracy: 0.4818 - val_loss: 2.0802 - val_accuracy: 0.2937
# Epoch 3/5
# 30/30 [==============================] - 0s 16ms/step - loss: 1.2526 - accuracy: 0.5773 - val_loss: 2.0120 - val_accuracy: 0.3521
# Epoch 4/5
# 30/30 [==============================] - 1s 18ms/step - loss: 1.0163 - accuracy: 0.6721 - val_loss: 1.9519 - val_accuracy: 0.3750
# Epoch 5/5
# 30/30 [==============================] - 1s 17ms/step - loss: 0.8353 - accuracy: 0.7461 - val_loss: 1.8756 - val_accuracy: 0.4031
# Epoch 1/5
# 30/30 [==============================] - 1s 20ms/step - loss: 2.0421 - accuracy: 0.2945 - val_loss: 2.1918 - val_accuracy: 0.1531
# Epoch 2/5
# 30/30 [==============================] - 0s 16ms/step - loss: 1.4760 - accuracy: 0.4828 - val_loss: 2.1286 - val_accuracy: 0.2167
# Epoch 3/5
# 30/30 [==============================] - 0s 15ms/step - loss: 1.2206 - accuracy: 0.5862 - val_loss: 2.0669 - val_accuracy: 0.2729
# Epoch 4/5
# 30/30 [==============================] - 1s 17ms/step - loss: 1.0412 - accuracy: 0.6560 - val_loss: 2.0574 - val_accuracy: 0.2490
# Epoch 5/5
# 30/30 [==============================] - 0s 16ms/step - loss: 0.8820 - accuracy: 0.7260 - val_loss: 1.9614 - val_accuracy: 0.3219
# Epoch 1/5
# 30/30 [==============================] - 1s 26ms/step - loss: 1.9827 - accuracy: 0.3094 - val_loss: 2.1956 - val_accuracy: 0.2188
# Epoch 2/5
# 30/30 [==============================] - 1s 22ms/step - loss: 1.3774 - accuracy: 0.5219 - val_loss: 2.1585 - val_accuracy: 0.2302
# Epoch 3/5
# 30/30 [==============================] - 1s 22ms/step - loss: 1.0624 - accuracy: 0.6469 - val_loss: 2.0909 - val_accuracy: 0.3521
# Epoch 4/5
# 30/30 [==============================] - 1s 21ms/step - loss: 0.8098 - accuracy: 0.7391 - val_loss: 2.0606 - val_accuracy: 0.3156
# Epoch 5/5
# 30/30 [==============================] - 1s 24ms/step - loss: 0.5782 - accuracy: 0.8404 - val_loss: 1.9928 - val_accuracy: 0.3583
# Epoch 1/5
# 30/30 [==============================] - 1s 25ms/step - loss: 2.0286 - accuracy: 0.2922 - val_loss: 2.2057 - val_accuracy: 0.1813
# Epoch 2/5
# 30/30 [==============================] - 1s 21ms/step - loss: 1.4530 - accuracy: 0.4872 - val_loss: 2.1457 - val_accuracy: 0.2302
# Epoch 3/5
# 30/30 [==============================] - 1s 21ms/step - loss: 1.1497 - accuracy: 0.6078 - val_loss: 2.0775 - val_accuracy: 0.2542
# Epoch 4/5
# 30/30 [==============================] - 1s 21ms/step - loss: 0.8994 - accuracy: 0.7125 - val_loss: 2.0216 - val_accuracy: 0.2917
# Epoch 5/5
# 30/30 [==============================] - 1s 25ms/step - loss: 0.7108 - accuracy: 0.7742 - val_loss: 1.9275 - val_accuracy: 0.3469
# Epoch 1/5
# 30/30 [==============================] - 1s 24ms/step - loss: 2.0558 - accuracy: 0.3016 - val_loss: 2.1882 - val_accuracy: 0.2094
# Epoch 2/5
# 30/30 [==============================] - 1s 22ms/step - loss: 1.4543 - accuracy: 0.4971 - val_loss: 2.0976 - val_accuracy: 0.2646
# Epoch 3/5
# 30/30 [==============================] - 1s 22ms/step - loss: 1.1273 - accuracy: 0.6203 - val_loss: 2.0402 - val_accuracy: 0.2990
# Epoch 4/5
# 30/30 [==============================] - 1s 21ms/step - loss: 0.8601 - accuracy: 0.7250 - val_loss: 1.9666 - val_accuracy: 0.3479
# Epoch 5/5
# 30/30 [==============================] - 1s 23ms/step - loss: 0.6359 - accuracy: 0.8208 - val_loss: 1.9152 - val_accuracy: 0.3562
# Epoch 1/5
# 30/30 [==============================] - 1s 23ms/step - loss: 1.9512 - accuracy: 0.3141 - val_loss: 2.2228 - val_accuracy: 0.1396
# Epoch 2/5
# 30/30 [==============================] - 1s 22ms/step - loss: 1.3799 - accuracy: 0.5273 - val_loss: 2.1766 - val_accuracy: 0.1740
# Epoch 3/5
# 30/30 [==============================] - 1s 22ms/step - loss: 1.0816 - accuracy: 0.6513 - val_loss: 2.0966 - val_accuracy: 0.2562
# Epoch 4/5
# 30/30 [==============================] - 1s 20ms/step - loss: 0.8325 - accuracy: 0.7406 - val_loss: 2.0432 - val_accuracy: 0.3115
# Epoch 5/5
# 30/30 [==============================] - 1s 20ms/step - loss: 0.6213 - accuracy: 0.8279 - val_loss: 2.0053 - val_accuracy: 0.3187
# Epoch 1/5
# 30/30 [==============================] - 1s 24ms/step - loss: 2.0205 - accuracy: 0.3052 - val_loss: 2.1870 - val_accuracy: 0.1354
# Epoch 2/5
# 30/30 [==============================] - 1s 21ms/step - loss: 1.3933 - accuracy: 0.5143 - val_loss: 2.1135 - val_accuracy: 0.2042
# Epoch 3/5
# 30/30 [==============================] - 1s 19ms/step - loss: 1.0857 - accuracy: 0.6326 - val_loss: 2.0630 - val_accuracy: 0.3417
# Epoch 4/5
# 30/30 [==============================] - 1s 23ms/step - loss: 0.8329 - accuracy: 0.7445 - val_loss: 2.0107 - val_accuracy: 0.2927
# Epoch 5/5
# 30/30 [==============================] - 1s 21ms/step - loss: 0.6343 - accuracy: 0.8156 - val_loss: 1.9433 - val_accuracy: 0.3531
# Epoch 1/5
# 30/30 [==============================] - 1s 41ms/step - loss: 1.9529 - accuracy: 0.3367 - val_loss: 2.1847 - val_accuracy: 0.2740
# Epoch 2/5
# 30/30 [==============================] - 1s 35ms/step - loss: 1.2881 - accuracy: 0.5479 - val_loss: 2.1210 - val_accuracy: 0.3115
# Epoch 3/5
# 30/30 [==============================] - 1s 37ms/step - loss: 0.9622 - accuracy: 0.6750 - val_loss: 2.0783 - val_accuracy: 0.3656
# Epoch 4/5
# 30/30 [==============================] - 1s 37ms/step - loss: 0.6899 - accuracy: 0.7885 - val_loss: 1.9943 - val_accuracy: 0.3917
# Epoch 5/5
# 30/30 [==============================] - 1s 40ms/step - loss: 0.4737 - accuracy: 0.8625 - val_loss: 1.9257 - val_accuracy: 0.4187
# Epoch 1/5
# 30/30 [==============================] - 1s 40ms/step - loss: 1.9811 - accuracy: 0.3258 - val_loss: 2.1825 - val_accuracy: 0.2302
# Epoch 2/5
# 30/30 [==============================] - 1s 37ms/step - loss: 1.2450 - accuracy: 0.5620 - val_loss: 2.1223 - val_accuracy: 0.2479
# Epoch 3/5
# 30/30 [==============================] - 1s 34ms/step - loss: 0.8979 - accuracy: 0.6891 - val_loss: 2.0858 - val_accuracy: 0.2865
# Epoch 4/5
# 30/30 [==============================] - 1s 38ms/step - loss: 0.6154 - accuracy: 0.8104 - val_loss: 1.9939 - val_accuracy: 0.3396
# Epoch 5/5
# 30/30 [==============================] - 1s 38ms/step - loss: 0.4163 - accuracy: 0.8872 - val_loss: 1.9148 - val_accuracy: 0.3812
# Epoch 1/5
# 30/30 [==============================] - 1s 41ms/step - loss: 1.8801 - accuracy: 0.3430 - val_loss: 2.1825 - val_accuracy: 0.2271
# Epoch 2/5
# 30/30 [==============================] - 1s 36ms/step - loss: 1.2123 - accuracy: 0.5826 - val_loss: 2.1366 - val_accuracy: 0.3292
# Epoch 3/5
# 30/30 [==============================] - 1s 38ms/step - loss: 0.8589 - accuracy: 0.7159 - val_loss: 2.0815 - val_accuracy: 0.3469
# Epoch 4/5
# 30/30 [==============================] - 1s 35ms/step - loss: 0.5652 - accuracy: 0.8393 - val_loss: 2.0170 - val_accuracy: 0.3740
# Epoch 5/5
# 30/30 [==============================] - 1s 40ms/step - loss: 0.3588 - accuracy: 0.9112 - val_loss: 1.9357 - val_accuracy: 0.4219
# Epoch 1/5
# 30/30 [==============================] - 1s 40ms/step - loss: 2.0358 - accuracy: 0.3125 - val_loss: 2.1729 - val_accuracy: 0.2313
# Epoch 2/5
# 30/30 [==============================] - 1s 37ms/step - loss: 1.3561 - accuracy: 0.5255 - val_loss: 2.1155 - val_accuracy: 0.2552
# Epoch 3/5
# 30/30 [==============================] - 1s 38ms/step - loss: 1.0123 - accuracy: 0.6573 - val_loss: 2.0852 - val_accuracy: 0.3010
# Epoch 4/5
# 30/30 [==============================] - 1s 35ms/step - loss: 0.7379 - accuracy: 0.7672 - val_loss: 2.0265 - val_accuracy: 0.3646
# Epoch 5/5
# 30/30 [==============================] - 1s 37ms/step - loss: 0.5210 - accuracy: 0.8544 - val_loss: 1.9451 - val_accuracy: 0.3583
# Epoch 1/5
# 30/30 [==============================] - 2s 43ms/step - loss: 1.8856 - accuracy: 0.3333 - val_loss: 2.1875 - val_accuracy: 0.2156
# Epoch 2/5
# 30/30 [==============================] - 1s 37ms/step - loss: 1.2244 - accuracy: 0.5849 - val_loss: 2.1477 - val_accuracy: 0.2573
# Epoch 3/5
# 30/30 [==============================] - 1s 45ms/step - loss: 0.8693 - accuracy: 0.7146 - val_loss: 2.1000 - val_accuracy: 0.3031
# Epoch 4/5
# 30/30 [==============================] - 1s 43ms/step - loss: 0.6333 - accuracy: 0.8052 - val_loss: 2.0477 - val_accuracy: 0.3479
# Epoch 5/5
# 30/30 [==============================] - 1s 42ms/step - loss: 0.4077 - accuracy: 0.8888 - val_loss: 1.9814 - val_accuracy: 0.4042
# Epoch 1/5
# 30/30 [==============================] - 3s 80ms/step - loss: 2.2473 - accuracy: 0.3135 - val_loss: 2.2202 - val_accuracy: 0.2042
# Epoch 2/5
# 30/30 [==============================] - 2s 74ms/step - loss: 1.3371 - accuracy: 0.5328 - val_loss: 2.1477 - val_accuracy: 0.3344
# Epoch 3/5
# 30/30 [==============================] - 2s 76ms/step - loss: 0.9428 - accuracy: 0.6768 - val_loss: 2.0963 - val_accuracy: 0.3365
# Epoch 4/5
# 30/30 [==============================] - 2s 75ms/step - loss: 0.6359 - accuracy: 0.7969 - val_loss: 2.0417 - val_accuracy: 0.3896
# Epoch 5/5
# 30/30 [==============================] - 2s 75ms/step - loss: 0.4184 - accuracy: 0.8854 - val_loss: 1.9565 - val_accuracy: 0.4542
# Epoch 1/5
# 30/30 [==============================] - 3s 83ms/step - loss: 2.0424 - accuracy: 0.3167 - val_loss: 2.2108 - val_accuracy: 0.2062
# Epoch 2/5
# 30/30 [==============================] - 2s 76ms/step - loss: 1.2815 - accuracy: 0.5521 - val_loss: 2.1581 - val_accuracy: 0.3385
# Epoch 3/5
# 30/30 [==============================] - 2s 74ms/step - loss: 0.8793 - accuracy: 0.7057 - val_loss: 2.1163 - val_accuracy: 0.4083
# Epoch 4/5
# 30/30 [==============================] - 2s 72ms/step - loss: 0.5822 - accuracy: 0.8211 - val_loss: 2.0514 - val_accuracy: 0.4344
# Epoch 5/5
# 30/30 [==============================] - 2s 74ms/step - loss: 0.3615 - accuracy: 0.9068 - val_loss: 1.9767 - val_accuracy: 0.4500
# Epoch 1/5
# 30/30 [==============================] - 3s 78ms/step - loss: 1.9536 - accuracy: 0.3516 - val_loss: 2.1918 - val_accuracy: 0.2604
# Epoch 2/5
# 30/30 [==============================] - 2s 75ms/step - loss: 1.2089 - accuracy: 0.5784 - val_loss: 2.1336 - val_accuracy: 0.2740
# Epoch 3/5
# 30/30 [==============================] - 2s 75ms/step - loss: 0.8322 - accuracy: 0.7289 - val_loss: 2.1104 - val_accuracy: 0.3052
# Epoch 4/5
# 30/30 [==============================] - 2s 74ms/step - loss: 0.5554 - accuracy: 0.8284 - val_loss: 2.0542 - val_accuracy: 0.3562
# Epoch 5/5
# 30/30 [==============================] - 2s 73ms/step - loss: 0.3500 - accuracy: 0.9107 - val_loss: 1.9637 - val_accuracy: 0.3750
# Epoch 1/5
# 30/30 [==============================] - 3s 81ms/step - loss: 2.0154 - accuracy: 0.3393 - val_loss: 2.1960 - val_accuracy: 0.2760
# Epoch 2/5
# 30/30 [==============================] - 2s 78ms/step - loss: 1.2417 - accuracy: 0.5594 - val_loss: 2.1359 - val_accuracy: 0.4010
# Epoch 3/5
# 30/30 [==============================] - 2s 80ms/step - loss: 0.8474 - accuracy: 0.7224 - val_loss: 2.1037 - val_accuracy: 0.4458
# Epoch 4/5
# 30/30 [==============================] - 2s 71ms/step - loss: 0.5451 - accuracy: 0.8362 - val_loss: 2.0405 - val_accuracy: 0.4573
# Epoch 5/5
# 30/30 [==============================] - 2s 74ms/step - loss: 0.3514 - accuracy: 0.9049 - val_loss: 1.9674 - val_accuracy: 0.4760
# Epoch 1/5
# 30/30 [==============================] - 3s 78ms/step - loss: 2.0824 - accuracy: 0.3313 - val_loss: 2.2114 - val_accuracy: 0.1792
# Epoch 2/5
# 30/30 [==============================] - 2s 75ms/step - loss: 1.2797 - accuracy: 0.5620 - val_loss: 2.1608 - val_accuracy: 0.2740
# Epoch 3/5
# 30/30 [==============================] - 2s 74ms/step - loss: 0.9094 - accuracy: 0.6945 - val_loss: 2.1153 - val_accuracy: 0.3260
# Epoch 4/5
# 30/30 [==============================] - 2s 75ms/step - loss: 0.6134 - accuracy: 0.8120 - val_loss: 2.0519 - val_accuracy: 0.3448
# Epoch 5/5
# 30/30 [==============================] - 2s 72ms/step - loss: 0.3996 - accuracy: 0.8901 - val_loss: 1.9906 - val_accuracy: 0.3740
# Epoch 1/5
# 30/30 [==============================] - 5s 156ms/step - loss: 2.3591 - accuracy: 0.3021 - val_loss: 2.2260 - val_accuracy: 0.2698
# Epoch 2/5
# 30/30 [==============================] - 5s 154ms/step - loss: 1.3424 - accuracy: 0.5232 - val_loss: 2.1616 - val_accuracy: 0.3156
# Epoch 3/5
# 30/30 [==============================] - 4s 148ms/step - loss: 0.9674 - accuracy: 0.6716 - val_loss: 2.1132 - val_accuracy: 0.4510
# Epoch 4/5
# 30/30 [==============================] - 5s 150ms/step - loss: 0.6645 - accuracy: 0.7852 - val_loss: 2.0506 - val_accuracy: 0.4271
# Epoch 5/5
# 30/30 [==============================] - 4s 149ms/step - loss: 0.4151 - accuracy: 0.8898 - val_loss: 1.9791 - val_accuracy: 0.4396
# Epoch 1/5
# 30/30 [==============================] - 5s 166ms/step - loss: 2.4205 - accuracy: 0.2948 - val_loss: 2.2156 - val_accuracy: 0.1510
# Epoch 2/5
# 30/30 [==============================] - 5s 158ms/step - loss: 1.4223 - accuracy: 0.4974 - val_loss: 2.1479 - val_accuracy: 0.3448
# Epoch 3/5
# 30/30 [==============================] - 5s 158ms/step - loss: 1.0499 - accuracy: 0.6333 - val_loss: 2.0935 - val_accuracy: 0.3948
# Epoch 4/5
# 30/30 [==============================] - 5s 155ms/step - loss: 0.7151 - accuracy: 0.7669 - val_loss: 2.0317 - val_accuracy: 0.4417
# Epoch 5/5
# 30/30 [==============================] - 5s 158ms/step - loss: 0.4783 - accuracy: 0.8596 - val_loss: 1.9685 - val_accuracy: 0.4563
# Epoch 1/5
# 30/30 [==============================] - 5s 156ms/step - loss: 2.4077 - accuracy: 0.3021 - val_loss: 2.2270 - val_accuracy: 0.3229
# Epoch 2/5
# 30/30 [==============================] - 5s 162ms/step - loss: 1.3564 - accuracy: 0.5258 - val_loss: 2.1612 - val_accuracy: 0.4052
# Epoch 3/5
# 30/30 [==============================] - 5s 161ms/step - loss: 0.9645 - accuracy: 0.6687 - val_loss: 2.1052 - val_accuracy: 0.4156
# Epoch 4/5
# 30/30 [==============================] - 5s 167ms/step - loss: 0.6469 - accuracy: 0.7859 - val_loss: 2.0278 - val_accuracy: 0.4740
# Epoch 5/5
# 30/30 [==============================] - 5s 163ms/step - loss: 0.4335 - accuracy: 0.8729 - val_loss: 1.9485 - val_accuracy: 0.4906
# Epoch 1/5
# 30/30 [==============================] - 5s 160ms/step - loss: 2.3254 - accuracy: 0.3143 - val_loss: 2.2211 - val_accuracy: 0.3458
# Epoch 2/5
# 30/30 [==============================] - 5s 155ms/step - loss: 1.3347 - accuracy: 0.5279 - val_loss: 2.1635 - val_accuracy: 0.3969
# Epoch 3/5
# 30/30 [==============================] - 5s 157ms/step - loss: 0.9723 - accuracy: 0.6630 - val_loss: 2.1413 - val_accuracy: 0.4458
# Epoch 4/5
# 30/30 [==============================] - 5s 156ms/step - loss: 0.6905 - accuracy: 0.7763 - val_loss: 2.0878 - val_accuracy: 0.4479
# Epoch 5/5
# 30/30 [==============================] - 5s 154ms/step - loss: 0.4811 - accuracy: 0.8523 - val_loss: 2.0071 - val_accuracy: 0.4729
# Epoch 1/5
# 30/30 [==============================] - 5s 158ms/step - loss: 2.3939 - accuracy: 0.3055 - val_loss: 2.2132 - val_accuracy: 0.3698
# Epoch 2/5
# 30/30 [==============================] - 5s 156ms/step - loss: 1.3814 - accuracy: 0.5138 - val_loss: 2.1613 - val_accuracy: 0.3260
# Epoch 3/5
# 30/30 [==============================] - 5s 156ms/step - loss: 0.9759 - accuracy: 0.6656 - val_loss: 2.1112 - val_accuracy: 0.4094
# Epoch 4/5
# 30/30 [==============================] - 5s 164ms/step - loss: 0.6445 - accuracy: 0.7958 - val_loss: 2.0409 - val_accuracy: 0.4719
# Epoch 5/5
# 30/30 [==============================] - 5s 152ms/step - loss: 0.4095 - accuracy: 0.8833 - val_loss: 1.9737 - val_accuracy: 0.4552
# 38/38 [==============================] - 1s 14ms/step - loss: 1.8642 - accuracy: 0.4825
# Epoch 1/5
# 30/30 [==============================] - 1s 23ms/step - loss: 2.0469 - accuracy: 0.2862 - val_loss: 2.1816 - val_accuracy: 0.2292
# Epoch 2/5
# 30/30 [==============================] - 1s 18ms/step - loss: 1.4760 - accuracy: 0.4789 - val_loss: 2.1125 - val_accuracy: 0.2802
# Epoch 3/5
# 30/30 [==============================] - 1s 21ms/step - loss: 1.1818 - accuracy: 0.6010 - val_loss: 2.0621 - val_accuracy: 0.3260
# Epoch 4/5
# 30/30 [==============================] - 1s 20ms/step - loss: 0.9633 - accuracy: 0.6917 - val_loss: 2.0066 - val_accuracy: 0.3552
# Epoch 5/5
# 30/30 [==============================] - 1s 19ms/step - loss: 0.7727 - accuracy: 0.7711 - val_loss: 1.9424 - val_accuracy: 0.3823
# Epoch 1/5
# 30/30 [==============================] - 1s 22ms/step - loss: 2.1279 - accuracy: 0.2719 - val_loss: 2.2159 - val_accuracy: 0.1688
# Epoch 2/5
# 30/30 [==============================] - 1s 20ms/step - loss: 1.5722 - accuracy: 0.4536 - val_loss: 2.1166 - val_accuracy: 0.2219
# Epoch 3/5
# 30/30 [==============================] - 1s 19ms/step - loss: 1.2921 - accuracy: 0.5633 - val_loss: 2.0670 - val_accuracy: 0.2521
# Epoch 4/5
# 30/30 [==============================] - 1s 19ms/step - loss: 1.0780 - accuracy: 0.6482 - val_loss: 2.0265 - val_accuracy: 0.2656
# Epoch 5/5
# 30/30 [==============================] - 1s 19ms/step - loss: 0.9143 - accuracy: 0.7164 - val_loss: 1.9644 - val_accuracy: 0.3292
# Epoch 1/5
# 30/30 [==============================] - 1s 22ms/step - loss: 2.1381 - accuracy: 0.2703 - val_loss: 2.1624 - val_accuracy: 0.1792
# Epoch 2/5
# 30/30 [==============================] - 1s 18ms/step - loss: 1.6271 - accuracy: 0.4414 - val_loss: 2.1308 - val_accuracy: 0.1865
# Epoch 3/5
# 30/30 [==============================] - 1s 21ms/step - loss: 1.4125 - accuracy: 0.5159 - val_loss: 2.0280 - val_accuracy: 0.2625
# Epoch 4/5
# 30/30 [==============================] - 1s 18ms/step - loss: 1.2570 - accuracy: 0.5766 - val_loss: 1.9727 - val_accuracy: 0.2948
# Epoch 5/5
# 30/30 [==============================] - 1s 20ms/step - loss: 1.1120 - accuracy: 0.6378 - val_loss: 1.9563 - val_accuracy: 0.2917
# Epoch 1/5
# 30/30 [==============================] - 1s 22ms/step - loss: 2.1476 - accuracy: 0.2641 - val_loss: 2.2737 - val_accuracy: 0.1594
# Epoch 2/5
# 30/30 [==============================] - 1s 20ms/step - loss: 1.6675 - accuracy: 0.4185 - val_loss: 2.2239 - val_accuracy: 0.1760
# Epoch 3/5
# 30/30 [==============================] - 1s 19ms/step - loss: 1.4008 - accuracy: 0.5240 - val_loss: 2.1509 - val_accuracy: 0.2458
# Epoch 4/5
# 30/30 [==============================] - 1s 18ms/step - loss: 1.1616 - accuracy: 0.6224 - val_loss: 2.0945 - val_accuracy: 0.2688
# Epoch 5/5
# 30/30 [==============================] - 1s 18ms/step - loss: 0.9676 - accuracy: 0.6956 - val_loss: 2.0400 - val_accuracy: 0.2979
# Epoch 1/5
# 30/30 [==============================] - 1s 21ms/step - loss: 2.0991 - accuracy: 0.2599 - val_loss: 2.1875 - val_accuracy: 0.2333
# Epoch 2/5
# 30/30 [==============================] - 1s 17ms/step - loss: 1.5844 - accuracy: 0.4435 - val_loss: 2.1329 - val_accuracy: 0.2542
# Epoch 3/5
# 30/30 [==============================] - 1s 19ms/step - loss: 1.3280 - accuracy: 0.5409 - val_loss: 2.0725 - val_accuracy: 0.3083
# Epoch 4/5
# 30/30 [==============================] - 1s 18ms/step - loss: 1.1309 - accuracy: 0.6154 - val_loss: 2.0174 - val_accuracy: 0.3333
# Epoch 5/5
# 30/30 [==============================] - 1s 18ms/step - loss: 0.9379 - accuracy: 0.7081 - val_loss: 1.9388 - val_accuracy: 0.3854
# Epoch 1/5
# 30/30 [==============================] - 1s 29ms/step - loss: 1.9774 - accuracy: 0.3081 - val_loss: 2.2216 - val_accuracy: 0.1406
# Epoch 2/5
# 30/30 [==============================] - 1s 22ms/step - loss: 1.3985 - accuracy: 0.5138 - val_loss: 2.1569 - val_accuracy: 0.2417
# Epoch 3/5
# 30/30 [==============================] - 1s 26ms/step - loss: 1.0854 - accuracy: 0.6266 - val_loss: 2.1313 - val_accuracy: 0.2292
# Epoch 4/5
# 30/30 [==============================] - 1s 21ms/step - loss: 0.8182 - accuracy: 0.7469 - val_loss: 2.0765 - val_accuracy: 0.2854
# Epoch 5/5
# 30/30 [==============================] - 1s 25ms/step - loss: 0.6131 - accuracy: 0.8299 - val_loss: 2.0068 - val_accuracy: 0.3229
# Epoch 1/5
# 30/30 [==============================] - 1s 26ms/step - loss: 2.0243 - accuracy: 0.2945 - val_loss: 2.2419 - val_accuracy: 0.1458
# Epoch 2/5
# 30/30 [==============================] - 1s 24ms/step - loss: 1.3760 - accuracy: 0.5318 - val_loss: 2.1258 - val_accuracy: 0.2010
# Epoch 3/5
# 30/30 [==============================] - 1s 21ms/step - loss: 1.0397 - accuracy: 0.6534 - val_loss: 2.0621 - val_accuracy: 0.2510
# Epoch 4/5
# 30/30 [==============================] - 1s 25ms/step - loss: 0.8005 - accuracy: 0.7484 - val_loss: 2.0028 - val_accuracy: 0.3021
# Epoch 5/5
# 30/30 [==============================] - 1s 22ms/step - loss: 0.5907 - accuracy: 0.8346 - val_loss: 1.9205 - val_accuracy: 0.3479
# Epoch 1/5
# 30/30 [==============================] - 1s 24ms/step - loss: 1.9320 - accuracy: 0.3211 - val_loss: 2.1919 - val_accuracy: 0.2417
# Epoch 2/5
# 30/30 [==============================] - 1s 21ms/step - loss: 1.3127 - accuracy: 0.5445 - val_loss: 2.1530 - val_accuracy: 0.2604
# Epoch 3/5
# 30/30 [==============================] - 1s 26ms/step - loss: 0.9647 - accuracy: 0.6815 - val_loss: 2.0996 - val_accuracy: 0.3021
# Epoch 4/5
# 30/30 [==============================] - 1s 23ms/step - loss: 0.6937 - accuracy: 0.7932 - val_loss: 2.0469 - val_accuracy: 0.3510
# Epoch 5/5
# 30/30 [==============================] - 1s 24ms/step - loss: 0.4879 - accuracy: 0.8724 - val_loss: 1.9718 - val_accuracy: 0.3885
# Epoch 1/5
# 30/30 [==============================] - 1s 25ms/step - loss: 1.9928 - accuracy: 0.3076 - val_loss: 2.1971 - val_accuracy: 0.1844
# Epoch 2/5
# 30/30 [==============================] - 1s 24ms/step - loss: 1.4028 - accuracy: 0.5125 - val_loss: 2.1476 - val_accuracy: 0.2615
# Epoch 3/5
# 30/30 [==============================] - 1s 26ms/step - loss: 1.0774 - accuracy: 0.6427 - val_loss: 2.0995 - val_accuracy: 0.2656
# Epoch 4/5
# 30/30 [==============================] - 1s 23ms/step - loss: 0.8292 - accuracy: 0.7365 - val_loss: 2.0428 - val_accuracy: 0.2875
# Epoch 5/5
# 30/30 [==============================] - 1s 25ms/step - loss: 0.6339 - accuracy: 0.8198 - val_loss: 1.9727 - val_accuracy: 0.3323
# Epoch 1/5
# 30/30 [==============================] - 1s 25ms/step - loss: 1.9698 - accuracy: 0.3076 - val_loss: 2.1829 - val_accuracy: 0.2198
# Epoch 2/5
# 30/30 [==============================] - 1s 26ms/step - loss: 1.4111 - accuracy: 0.5203 - val_loss: 2.1232 - val_accuracy: 0.2583
# Epoch 3/5
# 30/30 [==============================] - 1s 25ms/step - loss: 1.1270 - accuracy: 0.6216 - val_loss: 2.0717 - val_accuracy: 0.2708
# Epoch 4/5
# 30/30 [==============================] - 1s 24ms/step - loss: 0.8691 - accuracy: 0.7237 - val_loss: 2.0100 - val_accuracy: 0.3750
# Epoch 5/5
# 30/30 [==============================] - 1s 27ms/step - loss: 0.6534 - accuracy: 0.8042 - val_loss: 1.9409 - val_accuracy: 0.4146
# Epoch 1/5
# 30/30 [==============================] - 2s 44ms/step - loss: 2.0099 - accuracy: 0.3289 - val_loss: 2.1908 - val_accuracy: 0.1917
# Epoch 2/5
# 30/30 [==============================] - 1s 42ms/step - loss: 1.2789 - accuracy: 0.5523 - val_loss: 2.1288 - val_accuracy: 0.2948
# Epoch 3/5
# 30/30 [==============================] - 1s 41ms/step - loss: 0.9486 - accuracy: 0.6737 - val_loss: 2.0654 - val_accuracy: 0.3135
# Epoch 4/5
# 30/30 [==============================] - 1s 40ms/step - loss: 0.6572 - accuracy: 0.7911 - val_loss: 2.0143 - val_accuracy: 0.3531
# Epoch 5/5
# 30/30 [==============================] - 1s 40ms/step - loss: 0.4754 - accuracy: 0.8599 - val_loss: 1.9566 - val_accuracy: 0.4010
# Epoch 1/5
# 30/30 [==============================] - 2s 44ms/step - loss: 2.0533 - accuracy: 0.3125 - val_loss: 2.1946 - val_accuracy: 0.2344
# Epoch 2/5
# 30/30 [==============================] - 1s 42ms/step - loss: 1.3063 - accuracy: 0.5461 - val_loss: 2.1317 - val_accuracy: 0.3240
# Epoch 3/5
# 30/30 [==============================] - 1s 39ms/step - loss: 0.8958 - accuracy: 0.6971 - val_loss: 2.0760 - val_accuracy: 0.3573
# Epoch 4/5
# 30/30 [==============================] - 1s 40ms/step - loss: 0.5773 - accuracy: 0.8354 - val_loss: 2.0211 - val_accuracy: 0.4010
# Epoch 5/5
# 30/30 [==============================] - 1s 41ms/step - loss: 0.3793 - accuracy: 0.9070 - val_loss: 1.9565 - val_accuracy: 0.4115
# Epoch 1/5
# 30/30 [==============================] - 2s 42ms/step - loss: 1.9653 - accuracy: 0.3258 - val_loss: 2.1849 - val_accuracy: 0.2740
# Epoch 2/5
# 30/30 [==============================] - 1s 39ms/step - loss: 1.2729 - accuracy: 0.5615 - val_loss: 2.1490 - val_accuracy: 0.2635
# Epoch 3/5
# 30/30 [==============================] - 1s 41ms/step - loss: 0.9025 - accuracy: 0.7052 - val_loss: 2.0950 - val_accuracy: 0.3052
# Epoch 4/5
# 30/30 [==============================] - 1s 40ms/step - loss: 0.6232 - accuracy: 0.8109 - val_loss: 2.0221 - val_accuracy: 0.3760
# Epoch 5/5
# 30/30 [==============================] - 1s 39ms/step - loss: 0.4135 - accuracy: 0.8935 - val_loss: 1.9653 - val_accuracy: 0.4073
# Epoch 1/5
# 30/30 [==============================] - 1s 42ms/step - loss: 1.9415 - accuracy: 0.3432 - val_loss: 2.1970 - val_accuracy: 0.2219
# Epoch 2/5
# 30/30 [==============================] - 1s 39ms/step - loss: 1.2667 - accuracy: 0.5487 - val_loss: 2.1415 - val_accuracy: 0.2458
# Epoch 3/5
# 30/30 [==============================] - 1s 39ms/step - loss: 0.9178 - accuracy: 0.6883 - val_loss: 2.0753 - val_accuracy: 0.3490
# Epoch 4/5
# 30/30 [==============================] - 1s 38ms/step - loss: 0.6444 - accuracy: 0.7995 - val_loss: 2.0048 - val_accuracy: 0.4354
# Epoch 5/5
# 30/30 [==============================] - 1s 40ms/step - loss: 0.4237 - accuracy: 0.8893 - val_loss: 1.9250 - val_accuracy: 0.4573
# Epoch 1/5
# 30/30 [==============================] - 1s 42ms/step - loss: 2.0171 - accuracy: 0.3203 - val_loss: 2.2052 - val_accuracy: 0.2062
# Epoch 2/5
# 30/30 [==============================] - 1s 38ms/step - loss: 1.3183 - accuracy: 0.5391 - val_loss: 2.1332 - val_accuracy: 0.2438
# Epoch 3/5
# 30/30 [==============================] - 1s 39ms/step - loss: 0.9278 - accuracy: 0.6875 - val_loss: 2.0682 - val_accuracy: 0.3448
# Epoch 4/5
# 30/30 [==============================] - 1s 38ms/step - loss: 0.6269 - accuracy: 0.8036 - val_loss: 1.9984 - val_accuracy: 0.3427
# Epoch 5/5
# 30/30 [==============================] - 1s 41ms/step - loss: 0.4090 - accuracy: 0.8896 - val_loss: 1.9253 - val_accuracy: 0.3479
# Epoch 1/5
# 30/30 [==============================] - 3s 80ms/step - loss: 1.9357 - accuracy: 0.3424 - val_loss: 2.1879 - val_accuracy: 0.2708
# Epoch 2/5
# 30/30 [==============================] - 2s 73ms/step - loss: 1.2318 - accuracy: 0.5688 - val_loss: 2.1438 - val_accuracy: 0.3146
# Epoch 3/5
# 30/30 [==============================] - 2s 74ms/step - loss: 0.8287 - accuracy: 0.7193 - val_loss: 2.0779 - val_accuracy: 0.3604
# Epoch 4/5
# 30/30 [==============================] - 2s 75ms/step - loss: 0.5347 - accuracy: 0.8352 - val_loss: 2.0201 - val_accuracy: 0.4167
# Epoch 5/5
# 30/30 [==============================] - 2s 78ms/step - loss: 0.3081 - accuracy: 0.9273 - val_loss: 1.9380 - val_accuracy: 0.4281
# Epoch 1/5
# 30/30 [==============================] - 3s 78ms/step - loss: 2.2652 - accuracy: 0.3112 - val_loss: 2.1987 - val_accuracy: 0.1969
# Epoch 2/5
# 30/30 [==============================] - 2s 77ms/step - loss: 1.3335 - accuracy: 0.5424 - val_loss: 2.1306 - val_accuracy: 0.2469
# Epoch 3/5
# 30/30 [==============================] - 2s 80ms/step - loss: 0.9669 - accuracy: 0.6734 - val_loss: 2.0834 - val_accuracy: 0.3417
# Epoch 4/5
# 30/30 [==============================] - 2s 77ms/step - loss: 0.6372 - accuracy: 0.8036 - val_loss: 2.0126 - val_accuracy: 0.3771
# Epoch 5/5
# 30/30 [==============================] - 2s 80ms/step - loss: 0.4101 - accuracy: 0.8857 - val_loss: 1.9395 - val_accuracy: 0.4260
# Epoch 1/5
# 30/30 [==============================] - 3s 84ms/step - loss: 1.9989 - accuracy: 0.3456 - val_loss: 2.2164 - val_accuracy: 0.2771
# Epoch 2/5
# 30/30 [==============================] - ETA: 0s - loss: 1.2422 - accuracy: 0.5638
